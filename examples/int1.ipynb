# %%
int! \int \frac {x^2 dx}(1-x^2)^3
# Out:
# <div style="margin-top:4px"><strong>verified chain</strong> <span style="color:#888">&mdash; rendered from the selected ledger spine</span></div><table style="border-collapse:collapse"><tr><th style="padding:2px 12px 2px 0;text-align:left;border-bottom:1px solid #8884">step</th><th style="padding:2px 12px 2px 0;text-align:left;border-bottom:1px solid #8884">move</th><th style="padding:2px 12px 2px 0;text-align:left;border-bottom:1px solid #8884">result</th><th style="padding:2px 12px 2px 0;text-align:left;border-bottom:1px solid #8884">check</th></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s49</code><div class="tex2jax_ignore" style="color:#888;font-size:85%">new chain; no marker</div></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>integrate_substitute</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$\int \left(-\frac{1}{2u^{3}}\right) \, d u$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s50</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>integrate_power_rule</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$\frac{\frac {1} {4}}{u^{2}} + C$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s51</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>substitute</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$\frac {\frac {1} {4}} {(1-x^{2})^{2}}+C$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s52</code><div class="tex2jax_ignore" style="color:#888;font-size:85%">new chain; no marker</div></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>match_coefficients</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$0 = 2A-2B, 1 = -4A+6C, 0 = 2A+2B+2C$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s53</code><div class="tex2jax_ignore" style="color:#888;font-size:85%">new chain; no marker</div></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>apply_both_sides / 2</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$\frac{0}{2} = \frac{2A-2B}{2}$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s54</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>expand</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$0 = A-B$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s55</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>apply_both_sides + B</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$0 + B = A-B + B$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s56</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>expand</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$B = A$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">ag ...
# <div class="tex2jax_ignore"><em>Verified result recorded. The logarithm steps carry the assumptions \(1-x&gt;0\) and \(1+x&gt;0\), i.e. \(-1&lt;x&lt;1\).</em></div>
# <div style="color:#888">assumptions: $u > 0$</div>
# $- \left (- \frac {1} {16}\ln\left ((1-x) \right ) \right )- \left ( \frac {1} {16}\ln\left ((1+x) \right ) \right )- \left ( \frac {\frac {1} {16}} {1-x}\right )- \left (- \frac {\frac {1} {16}} {1+x}\right )+ \left ( \frac {\frac {1} {16}} {(1-x)^{2}}\right )+ \left (- \frac {\frac {1} {16}} {(1+x)^{2}}\right )+C$

# %%
simplify! [[6]]
# Out:
# <div style="margin-top:4px"><strong>verified chain</strong> <span style="color:#888">&mdash; rendered from the selected ledger spine</span></div><table style="border-collapse:collapse"><tr><th style="padding:2px 12px 2px 0;text-align:left;border-bottom:1px solid #8884">step</th><th style="padding:2px 12px 2px 0;text-align:left;border-bottom:1px solid #8884">move</th><th style="padding:2px 12px 2px 0;text-align:left;border-bottom:1px solid #8884">result</th><th style="padding:2px 12px 2px 0;text-align:left;border-bottom:1px solid #8884">check</th></tr><tr><td colspan="4" style="padding:3px 12px 3px 0;text-align:left;vertical-align:top"><details><summary><span class="tex2jax_ignore"><strong>abandoned path from s123</strong> &mdash; The global expansion is less readable, so resume from the recorded input and simplify signs first. (1 checked step; resumed as s125)</span></summary><div style="display:grid;grid-template-columns:5em 11em minmax(12em,1fr) 9em;column-gap:12px;padding:2px 0"><div><code>s123</code></div><div><code>expand</code></div><div>$\frac {Cx^{6}+ \frac {1} {16}x^{6}\ln\left ((-x+1) \right )- \frac {1} {16}x^{6}\ln\left ((x+1) \right )-3Cx^{4}+ \frac {1} {8}x^{5}- \frac {3} {16}x^{4}\ln\left ((-x+1) \right )+ \frac {3} {16}x^{4}\ln\left ((x+1) \right )+3Cx^{2}+ \frac {3} {16}x^{2}\ln\left ((-x+1) \right )- \frac {3} {16}x^{2}\ln\left ((x+1) \right )-C- \frac {1} {8}x- \frac {1} {16}\ln\left ((-x+1) \right )+ \frac {1} {16}\ln\left ((x+1) \right )} {x^{6}-3x^{4}+3x^{2}-1}$</div><div style="color:#176b2c">agree</div></div></details></td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s125</code><div class="tex2jax_ignore" style="color:#888;font-size:85%">resumed from s123 via s124</div></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>rewrite_as</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$\frac{1}{16}\ln(1-x)-\frac{1}{16}\ln(1+x)-\frac{1}{16(1-x)}+\frac{1}{16(1+x)}+\frac{1}{16(1-x)^2}-\frac{1}{16(1+x)^2}+C$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s126</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>rewrite_as</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$\frac{1}{16}\ln\left(\frac{1-x}{1+x}\right)-\frac{1}{16(1-x)}+\frac{1}{16(1+x)}+\frac{1}{16(1-x)^2}-\frac{1}{16(1+x)^2}+C$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree <span style="color:#888">+1 assum.</span></td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s127</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>rewrite_as</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$\frac{1}{16}\ln\left(\frac{1-x}{1+x}\right)-\frac{x}{8(1-x^2)}+\frac{1}{16(1-x)^2}-\frac{1}{16(1+x)^2}+C$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s128</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>rewrite_as</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$\frac{1}{16}\ln\left(\frac{1-x}{1+x}\right)-\frac{x}{8(1-x^2)}+\frac{x}{4(1-x^2)^2}+C$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s129</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>rewrite_as</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$\frac{1}{16}\ln\left(\frac{1-x}{1+x}\right)+\frac{x(1+x^2)}{8(1-x^2)^2}+C$</td><td style="padding:2px 12px 2px 0; ...
# <div class="tex2jax_ignore"><em>Combined the logarithms and rational terms into a shorter checked form.</em></div>
# <div style="color:#888">assumptions: $u > 0$; $x+1 \ne 0$; $-4x^{2}+4 \ne 0$</div>
# $\frac {1} {16}\ln\left ( \frac {1-x} {1+x}\right )+ \frac {x(1+x^{2})} {8(1-x^{2})^{2}}+C$

# %%
int! \int \frac {dx} (x^{\frac 1 2} + x^{\frac 1 3})
# Out:
# <div style="margin-top:4px"><strong>verified chain</strong> <span style="color:#888">&mdash; rendered from the selected ledger spine</span></div><table style="border-collapse:collapse"><tr><th style="padding:2px 12px 2px 0;text-align:left;border-bottom:1px solid #8884">step</th><th style="padding:2px 12px 2px 0;text-align:left;border-bottom:1px solid #8884">move</th><th style="padding:2px 12px 2px 0;text-align:left;border-bottom:1px solid #8884">result</th><th style="padding:2px 12px 2px 0;text-align:left;border-bottom:1px solid #8884">check</th></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s2</code><div class="tex2jax_ignore" style="color:#888;font-size:85%">new chain; no marker</div></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>integrate_substitute</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$\int \frac{6u^3}{u+1} \, d u$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s3</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>integrate_rewrite</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$\int \left(6u^2-6u+6-\frac{6}{u+1}\right) \, d u$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s4</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>integrate_linearity</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$\int 6u^{2} \, d u - \int 6u \, d u + \int 6 \, d u - \int \frac {6} {u+1} \, d u$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">exact</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s5</code><div class="tex2jax_ignore" style="color:#888;font-size:85%">new chain; no marker</div></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>integrate_power_rule</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$2u^{3} + C$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s6</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>substitute</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$2u^{3}$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s7</code><div class="tex2jax_ignore" style="color:#888;font-size:85%">new chain; no marker</div></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>integrate_power_rule</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$3u^{2} + C$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s8</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>substitute</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$3u^{2}$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s9</code><div class="tex2jax_ignore" style="color:#888;font-size:85%">new chain; no marker</div></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>integrate_table</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$6u + C$</td><td  ...
# <div class="tex2jax_ignore"><em>Verified on the recorded assumption \(x&gt;0\), with one fresh \(+C\).</em></div>
# <div style="color:#888">assumptions: $v > 0$; $x > 0$</div>
# $2x^{\frac {1} {2}}-3x^{\frac {1} {3}}+C+6x^{\frac {1} {6}}-6 \ln\left ((x^{\frac {1} {6}}+1) \right )$

# %%
int! \int \frac{d x}{2 \sin x-\cos x+5}
# Out:
# <div style="margin-top:4px"><strong>verified chain</strong> <span style="color:#888">&mdash; rendered from the selected ledger spine</span></div><table style="border-collapse:collapse"><tr><th style="padding:2px 12px 2px 0;text-align:left;border-bottom:1px solid #8884">step</th><th style="padding:2px 12px 2px 0;text-align:left;border-bottom:1px solid #8884">move</th><th style="padding:2px 12px 2px 0;text-align:left;border-bottom:1px solid #8884">result</th><th style="padding:2px 12px 2px 0;text-align:left;border-bottom:1px solid #8884">check</th></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s43</code><div class="tex2jax_ignore" style="color:#888;font-size:85%">new chain; no marker</div></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>integrate_substitute</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$\int \frac{1}{3t^2+2t+2} \, d t$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s44</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>integrate_rewrite</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$\int \frac{1}{3\left(t+\frac{1}{3}\right)^2+\frac{5}{3}} \, d t$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s45</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>integrate_substitute</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$\int \frac{1}{3u^2+\frac{5}{3}} \, d u$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s46</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>integrate_table</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$\frac{1}{\sqrt{5}} \arctan\left(\frac{3}{\sqrt{5}} u\right) + C$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s47</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>substitute</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$\frac {1} {\sqrt{5}}\arctan\left ( \frac {3} {\sqrt{5}}(t+ \frac {1} {3}) \right )+C$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s48</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>substitute</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$\frac {1} {\sqrt{5}}\arctan\left ( \frac {3} {\sqrt{5}}(( \tan\left ( \frac {x} {2}\right ))+ \frac {1} {3}) \right )+C$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree</td></tr></table>
# <div class="tex2jax_ignore"><em>The verified antiderivative has been recorded, with one fresh \(+C\) and no assumptions.</em></div>
# <div style="color:#888">rests on 1 stated premise, not derived here: \(\frac{1}{2\sin x-\cos x+5}\)</div>
# $\frac {1} {\sqrt{5}}\arctan\left ( \frac {3} {\sqrt{5}}(( \tan\left ( \frac {x} {2}\right ))+ \frac {1} {3}) \right )+C$

# %%
int! \int \frac{\sin x d x}{\sin ^3 x+\cos ^3 x}
# Out:
# <div style="margin-top:4px"><strong>verified chain</strong> <span style="color:#888">&mdash; rendered from the selected ledger spine</span></div><table style="border-collapse:collapse"><tr><th style="padding:2px 12px 2px 0;text-align:left;border-bottom:1px solid #8884">step</th><th style="padding:2px 12px 2px 0;text-align:left;border-bottom:1px solid #8884">move</th><th style="padding:2px 12px 2px 0;text-align:left;border-bottom:1px solid #8884">result</th><th style="padding:2px 12px 2px 0;text-align:left;border-bottom:1px solid #8884">check</th></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s2</code><div class="tex2jax_ignore" style="color:#888;font-size:85%">new chain; no marker</div></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>integrate_substitute</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$\int \frac{t}{t^3+1} \, d t$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s3</code><div class="tex2jax_ignore" style="color:#888;font-size:85%">new chain; no marker</div></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>match_coefficients</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$0 = A+B, 1 = -A+B+C, 0 = A+C$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s4</code><div class="tex2jax_ignore" style="color:#888;font-size:85%">new chain; no marker</div></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>apply_both_sides - A</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$0 - A = A+B - A$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s5</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>expand</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$-A = B$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s6</code><div class="tex2jax_ignore" style="color:#888;font-size:85%">new chain; no marker</div></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>substitute</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$1=-A+(-A)+C$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s7</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>expand</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$1 = -2A+C$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s8</code><div class="tex2jax_ignore" style="color:#888;font-size:85%">new chain; no marker</div></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>apply_both_sides - A</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$0 - A = A+C - A$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s9</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>expand</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$-A = C$</td><td style="padding:2 ...
# <div class="tex2jax_ignore"><em><strong>agent narrative — unverified:</strong> Verified antiderivative recorded, with the table-rule assumptions \(t+1&gt;0\) and \(t^2-t+1&gt;0\) surfaced in the ledger.</em></div>
# <div style="color:#888">assumptions: $v > 0$; $u > 0$</div>
# $- \left ( \frac {1} {3}\ln\left ((( \tan x)+1) \right ) \right )+ \left ( \left ( \frac {1} {6}\ln\left ((( \tan x)^{2}-( \tan x)+1) \right ) \right )+ \left ( \frac {1} {\sqrt{3}}\arctan\left ( \frac {2} {\sqrt{3}}(( \tan x)- \frac {1} {2}) \right ) \right ) \right )+C$

# %%
do! prove \begin{aligned}
& \int \frac{d x}{(a+b \cos x)^n}=\frac{A \sin x}{(a+b \cos x)^{n-1}}+ \\
& +B \int \frac{d x}{(a+b \cos x)^{n-1}}+C \int \frac{d x}{(a+b \cos x)^{n-2}}(|a| \neq|b|)
\end{aligned} if n > 1. Find A,B and C
# Out:
# <div style="margin-top:4px"><strong>verified chain</strong> <span style="color:#888">&mdash; rendered from the selected ledger spine</span></div><table style="border-collapse:collapse"><tr><th style="padding:2px 12px 2px 0;text-align:left;border-bottom:1px solid #8884">step</th><th style="padding:2px 12px 2px 0;text-align:left;border-bottom:1px solid #8884">move</th><th style="padding:2px 12px 2px 0;text-align:left;border-bottom:1px solid #8884">result</th><th style="padding:2px 12px 2px 0;text-align:left;border-bottom:1px solid #8884">check</th></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s40</code><div class="tex2jax_ignore" style="color:#888;font-size:85%">new chain; no marker</div></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>differentiate</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$\frac {bn( \sin\left (x \right ))^{2}{a+b \cos\left (x \right )}^{n-2}-b( \sin\left (x \right ))^{2}{a+b \cos\left (x \right )}^{n-2}+( \cos\left (x \right )){a+b \cos\left (x \right )}^{n-1}} {({a+b \cos\left (x \right )}^{n-1})^{2}}$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s41</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>rewrite_as</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$\frac{(n-1)b+a\cos x-(n-2)b\cos^2x}{(a+b\cos x)^n}$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s42</code><div class="tex2jax_ignore" style="color:#888;font-size:85%">new chain; no marker</div></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>rewrite_as</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$\frac{b}{(n-1)(b^2-a^2)}\frac{(n-1)b+a\cos x-(n-2)b\cos^2x}{(a+b\cos x)^n}-\frac{a(2n-3)}{(n-1)(b^2-a^2)}\frac{1}{(a+b\cos x)^{n-1}}+\frac{n-2}{(n-1)(b^2-a^2)}\frac{1}{(a+b\cos x)^{n-2}}$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree <span style="color:#888">+3 assum.</span></td></tr></table>
# <div class="tex2jax_ignore"><em>\[
# A=\frac{b}{(n-1)(b^2-a^2)},\qquad
# B=-\frac{a(2n-3)}{(n-1)(b^2-a^2)},\qquad
# C=\frac{n-2}{(n-1)(b^2-a^2)}.
# \]
#
# The verified integrand identity in the notebook, together with the differentiated leading term, yields the stated recurrence upon integration.</em></div>
# <div style="color:#888">rests on 1 stated premise, not derived here: \(\frac{1}{(a+b\cos x)^n}\)</div>
# <div style="color:#888">assumptions: $(n-1)(b^{2}-a^{2}) \ne 0$; $(a+b \cos x)^{n-1} \ne 0$; $(a+b \cos x)^{n-2} \ne 0$</div>
# $\frac {b} {(n-1)(b^{2}-a^{2})}\frac {(n-1)b+a \cos x-(n-2)b \cos^{2}x} {(a+b \cos x)^n}- \frac {a(2n-3)} {(n-1)(b^{2}-a^{2})}\frac {1} {(a+b \cos x)^{n-1}}+ \frac {n-2} {(n-1)(b^{2}-a^{2})}\frac {1} {(a+b \cos x)^{n-2}}$

# %%
int! \frac{d}{d x} \int_0^{x^2} \sqrt{1+t^2} d t
# Out:
# <div style="margin-top:4px"><strong>verified chain</strong> <span style="color:#888">&mdash; rendered from the selected ledger spine</span></div><table style="border-collapse:collapse"><tr><th style="padding:2px 12px 2px 0;text-align:left;border-bottom:1px solid #8884">step</th><th style="padding:2px 12px 2px 0;text-align:left;border-bottom:1px solid #8884">move</th><th style="padding:2px 12px 2px 0;text-align:left;border-bottom:1px solid #8884">result</th><th style="padding:2px 12px 2px 0;text-align:left;border-bottom:1px solid #8884">check</th></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s1</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>differentiate</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$2x \sqrt{x^{4}+1}$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree <span style="color:#888">+1 assum.</span></td></tr></table>
# <div class="tex2jax_ignore"><em>Verified result: \(2x\sqrt{x^{4}+1}\), assuming \(\sqrt{1+t^{2}}\) is continuous between \(0\) and \(x^{2}\).</em></div>
# <div style="color:#888">assumptions: $\sqrt{1+t^{2}}$ is continuous between $0$ and $x^{2}$</div>
# $2x \sqrt{x^{4}+1}$

# %%
int! \frac{d}{d x} \int_{\sin x}^{\cos x} \cos \left(\pi t^2\right) d t
# Out:
# <div style="margin-top:4px"><strong>verified chain</strong> <span style="color:#888">&mdash; rendered from the selected ledger spine</span></div><table style="border-collapse:collapse"><tr><th style="padding:2px 12px 2px 0;text-align:left;border-bottom:1px solid #8884">step</th><th style="padding:2px 12px 2px 0;text-align:left;border-bottom:1px solid #8884">move</th><th style="padding:2px 12px 2px 0;text-align:left;border-bottom:1px solid #8884">result</th><th style="padding:2px 12px 2px 0;text-align:left;border-bottom:1px solid #8884">check</th></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s18</code><div class="tex2jax_ignore" style="color:#888;font-size:85%">new chain; no marker</div></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>differentiate</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$- \cos\left ( \pi ( \cos x)^{2}\right ) \sin\left (x \right )- \cos\left ( \pi ( \sin x)^{2}\right ) \cos\left (x \right )$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree <span style="color:#888">+1 assum.</span></td></tr></table>
# <div class="tex2jax_ignore"><em>Verified result recorded. Assumption: \(\cos(\pi t^2)\) is continuous between the moving bounds.</em></div>
# <div style="color:#888">assumptions: $\cos\left ( \pi t^{2}\right )$ is continuous between $\sin x$ and $\cos x$</div>
# $- \cos\left ( \pi ( \cos x)^{2}\right ) \sin\left (x \right )- \cos\left ( \pi ( \sin x)^{2}\right ) \cos\left (x \right )$
