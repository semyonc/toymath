# %%
int! \int \frac {x^2 dx}(1-x^2)^3
# Out:
# <details style="margin:2px 0"><summary style="cursor:pointer;color:#888">agent turns &mdash; 59 steps &middot; 59 checked <span style="font-size:90%">(click to expand)</span></summary><div style="margin:4px 0 4px 1em;border-left:2px solid #eee;padding-left:.8em"><div><code>s1#60e5537 [ok] match_coefficients</code> &nbsp;$x^{2}=A((1-x)^{2}(1+x)^{3}+(1-x)^{3}(1+x)^{2})+B((1-x)(1+x)^{3}+(1-x)^{3}(1+x))+C((1+x)^{3}+(1-x)^{3}) \;\Longrightarrow\; 0 = 2A-2B, 1 = -4A+6C, 0 = 2A+2B+2C$</div><div><code>s2#8e72a83 [ok] (new chain; no marker) apply_both_sides / 2</code> &nbsp;$0=2A-2B \;\Longrightarrow\; \frac{0}{2} = \frac{2A-2B}{2}$</div><div><code>s3#e8846a4 [ok] expand</code> &nbsp;$\frac{0}{2} = \frac{2A-2B}{2} \;\Longrightarrow\; 0 = A-B$</div><div><code>s4#2a3ce54 [ok] apply_both_sides + B</code> &nbsp;$0 = A-B \;\Longrightarrow\; 0 + B = A-B + B$</div><div><code>s5#51c251e [ok] expand</code> &nbsp;$0 + B = A-B + B \;\Longrightarrow\; B = A$</div><div><code>s6#5997daf [ok] (new chain; no
# ...

# %%
simplify! [[1]]
# Out:
# <details style="margin:2px 0"><summary style="cursor:pointer;color:#888">agent turns &mdash; 5 steps &middot; 5 checked <span style="font-size:90%">(click to expand)</span></summary><div style="margin:4px 0 4px 1em;border-left:2px solid #eee;padding-left:.8em"><div><code>s60#a27d366 [ok] (new chain; no marker) expand</code> &nbsp;$\left( \frac{\frac{1}{16}}{1-x}\right)+\left(-\frac{\frac{1}{16}}{1+x}\right)+\left(\frac{\frac{1}{16}}{(1-x)^2}\right)+\left(-\frac{\frac{1}{16}}{(1+x)^2}\right) \;\Longrightarrow\; \frac {- \frac {1} {8}x^{3}+ \frac {3} {8}x} {x^{4}-2x^{2}+1}$</div><div style="margin-left:2em;color:#888">assumes $1-x \ne 0$</div><div style="margin-left:2em;color:#888">assumes $1+x \ne 0$</div><div><code>s61#6a746e4 [ok] rewrite_as</code> &nbsp;$\frac {- \frac {1} {8}x^{3}+ \frac {3} {8}x} {x^{4}-2x^{2}+1} \;\Longrightarrow\; \frac{x(3-x^2)}{8(1-x^2)^2}$</div><div><code>s62#e5738e1 [ok] (new chain; no marker) rewrite_as</code> &nbsp;$-\left(\left(-\frac{1}{16}\ln(1-x)\righ
# ...

# %%
int! \int \frac {dx} (x^{\frac 1 2} + x^{\frac 1 3})
# Out:
# <details style="margin:2px 0"><summary style="cursor:pointer;color:#888">agent turns &mdash; 16 steps &middot; 16 checked <span style="font-size:90%">(click to expand)</span></summary><div style="margin:4px 0 4px 1em;border-left:2px solid #eee;padding-left:.8em"><div><code>s65#f9b009f [ok] (new chain; no marker) integrate_substitute</code> &nbsp;$\frac{1}{x^{\frac{1}{2}}+x^{\frac{1}{3}}} \;\Longrightarrow\; \int \frac{6u^3}{u+1} \, d u$</div><div><code>s66#c917b44 [ok] integrate_rewrite</code> &nbsp;$\int \frac{6u^3}{u+1} \, d u \;\Longrightarrow\; \int \left(6u^2-6u+6-\frac{6}{u+1}\right) \, d u$</div><div><code>s67#c18558b [ok] integrate_linearity</code> &nbsp;$\int \left(6u^2-6u+6-\frac{6}{u+1}\right) \, d u \;\Longrightarrow\; \int 6u^{2} \, d u - \int 6u \, d u + \int 6 \, d u - \int \frac {6} {u+1} \, d u$</div><div><code>s68#a820156 [ok] (new chain; no marker) integrate_power_rule</code> &nbsp;$\int 6u^{2} \, d u \;\Longrightarrow\; 2u^{3} + C$</div><div><code>s69#7cbb449 [ok]
# ...

# %%
int! \int \frac{d x}{2 \sin x-\cos x+5}
# Out:
# <details style="margin:2px 0"><summary style="cursor:pointer;color:#888">agent turns &mdash; 6 steps &middot; 6 checked <span style="font-size:90%">(click to expand)</span></summary><div style="margin:4px 0 4px 1em;border-left:2px solid #eee;padding-left:.8em"><div><code>s81#75090cc [ok] (new chain; no marker) integrate_substitute</code> &nbsp;$\frac{1}{2\sin x-\cos x+5} \;\Longrightarrow\; \int \frac{1}{3t^2+2t+2} \, d t$</div><div><code>s82#4046311 [ok] integrate_rewrite</code> &nbsp;$\int \frac{1}{3t^2+2t+2} \, d t \;\Longrightarrow\; \int \frac{1}{3(t+\frac{1}{3})^2+\frac{5}{3}} \, d t$</div><div><code>s83#da08753 [ok] integrate_substitute</code> &nbsp;$\frac{1}{3(t+\frac{1}{3})^2+\frac{5}{3}} \;\Longrightarrow\; \int \frac{1}{3u^2+\frac{5}{3}} \, d u$</div><div><code>s84#1820f53 [ok] integrate_table</code> &nbsp;$\frac{1}{3u^2+\frac{5}{3}} \;\Longrightarrow\; \frac{1}{\sqrt{5}} \arctan\left(\frac{3}{\sqrt{5}} u\right) + C$</div><div><code>s85#e40eb40 [ok] substitute</code> &nbsp
# ...

# %%
int! \int \frac{\sin x d x}{\sin ^3 x+\cos ^3 x}
# Out:
# <details style="margin:2px 0"><summary style="cursor:pointer;color:#888">agent turns &mdash; 39 steps &middot; 37 checked &middot; 2 not checked &middot; 1 note <span style="font-size:90%">(click to expand)</span></summary><div style="margin:4px 0 4px 1em;border-left:2px solid #eee;padding-left:.8em"><div><code>s87#80880bc [ok] (new chain; no marker) integrate_substitute</code> &nbsp;$\frac{\sin x}{\sin^{3}x+\cos^{3}x} \;\Longrightarrow\; \int \frac{t}{t^{3}+1} \, d t$</div><div><code>s88#a40fa37 [ok] (new chain; no marker) match_coefficients</code> &nbsp;$t=A(t^{2}-t+1)+(Bt+C)(t+1) \;\Longrightarrow\; 0 = A+B, 1 = -A+B+C, 0 = A+C$</div><div><code>s89#b4fdf6d [ok] (new chain; no marker) apply_both_sides - A</code> &nbsp;$0 = A+C \;\Longrightarrow\; 0 - A = A+C - A$</div><div><code>s90#30d6a97 [ok] expand</code> &nbsp;$0 - A = A+C - A \;\Longrightarrow\; -A = C$</div><div><code>s91#d216c70 [ok] (new chain; no marker) substitute</code> &nbsp;$0 = A+B, 1 = -A+B+C, 0 = A+C \;\Longrightar
# ...

# %%
do! prove \begin{aligned}
& \int \frac{d x}{(a+b \cos x)^n}=\frac{A \sin x}{(a+b \cos x)^{n-1}}+ \\
& +B \int \frac{d x}{(a+b \cos x)^{n-1}}+C \int \frac{d x}{(a+b \cos x)^{n-2}}(|a| \neq|b|)
\end{aligned} if n > 1. Find A,B and C
# Out:
# <details style="margin:2px 0"><summary style="cursor:pointer;color:#888">agent turns &mdash; 29 steps &middot; 28 checked &middot; 1 not checked <span style="font-size:90%">(click to expand)</span></summary><div style="margin:4px 0 4px 1em;border-left:2px solid #eee;padding-left:.8em"><div><code>s1#3a9fbe4 [ok] differentiate</code> &nbsp;$\frac{A\sin x}{(a+b\cos x)^{n-1}} \;\Longrightarrow\; \frac {Abn( \sin\left (x \right ))^{2}{a+b \cos\left (x \right )}^{n-2}-Ab( \sin\left (x \right ))^{2}{a+b \cos\left (x \right )}^{n-2}+A( \cos\left (x \right )){a+b \cos\left (x \right )}^{n-1}} {({a+b \cos\left (x \right )}^{n-1})^{2}}$</div><div><code>s2#aa4df85 [ok] rewrite_as</code> &nbsp;$\frac {Abn( \sin\left (x \right ))^{2}{a+b \cos\left (x \right )}^{n-2}-Ab( \sin\left (x \right ))^{2}{a+b \cos\left (x \right )}^{n-2}+A( \cos\left (x \right )){a+b \cos\left (x \right )}^{n-1}} {({a+b \cos\left (x \right )}^{n-1})^{2}} \;\Longrightarrow\; \frac{A\cos x}{(a+b\cos x)^{n-1}}+\frac{Ab(n-1)\s
# ...

# %%
do! simplify A,B and C [[1]]
# Out:
# <details style="margin:2px 0"><summary style="cursor:pointer;color:#888">agent turns &mdash; 7 steps &middot; 7 checked <span style="font-size:90%">(click to expand)</span></summary><div style="margin:4px 0 4px 1em;border-left:2px solid #eee;padding-left:.8em"><div><code>s30#1fec897 [ok] (new chain; no marker) rewrite_as</code> &nbsp;$\frac{-b}{a^{2}n-b^{2}n-a^{2}+b^{2}} \;\Longrightarrow\; \frac{-b}{(a^{2}-b^{2})(n-1)}$</div><div><code>s31#76ed102 [ok] (new chain; no marker) rewrite_as</code> &nbsp;$\frac{2a^{3}n^{2}-2ab^{2}n^{2}-5a^{3}n+5ab^{2}n+3a^{3}-3ab^{2}}{a^{4}n^{2}-2a^{2}b^{2}n^{2}+b^{4}n^{2}-2a^{4}n+4a^{2}b^{2}n-2b^{4}n+a^{4}-2a^{2}b^{2}+b^{4}} \;\Longrightarrow\; \frac{a(2n-3)}{(a^{2}-b^{2})(n-1)}$</div><div style="margin-left:2em;color:#888">assumes $a^{2}n-b^{2}n-a^{2}+b^{2} \ne 0$</div><div><code>s32#7455063 [ok] (new chain; no marker) rewrite_as</code> &nbsp;$\frac{-a^{2}n^{2}+b^{2}n^{2}+3a^{2}n-3b^{2}n-2a^{2}+2b^{2}}{a^{4}n^{2}-2a^{2}b^{2}n^{2}+b^{4}n^{2}-2a^{4}n+4a^{
# ...

# %%
int! \frac{d}{d x} \int_0^{x^2} \sqrt{1+t^2} d t
# Out:
# <details style="margin:2px 0"><summary style="cursor:pointer;color:#888">agent turns &mdash; 1 step &middot; 1 checked &middot; 1 note <span style="font-size:90%">(click to expand)</span></summary><div style="margin:4px 0 4px 1em;border-left:2px solid #eee;padding-left:.8em"><div class="tex2jax_ignore" style="color:#666"><code>s136</code> <em>The integral has a variable upper limit, so I now cross to differentiation for the FTC and chain-rule step.</em></div><div><code>s137#e7598ec [ok] (new chain; no marker) differentiate</code> &nbsp;$\frac{d}{dx}\int_{0}^{x^{2}}\sqrt{1+t^{2}}\,dt \;\Longrightarrow\; 2x \sqrt{x^{4}+1}$</div><div style="margin-left:2em;color:#888">assumes $\sqrt{1+t^{2}}$ is continuous between $0$ and $x^{2}$</div></div></details>
# ...

# %%
int! \frac{d}{d x} \int_{\sin x}^{\cos x} \cos \left(\pi t^2\right) d t
# Out:
# <div><code>s138#40b21ff [ok] (new chain; no marker) differentiate</code> &nbsp;$\frac{d}{dx}\int_{\sin x}^{\cos x}\cos\left(\pi t^{2}\right)dt \;\Longrightarrow\; - \cos\left ( \pi ( \cos x)^{2}\right ) \sin\left (x \right )- \cos\left ( \pi ( \sin x)^{2}\right ) \cos\left (x \right )$</div><div style="margin-left:2em;color:#888">assumes $\cos\left ( \pi t^{2}\right )$ is continuous between $\sin x$ and $\cos x$</div>
# ...

# %%
int! \int_0^1 \frac{d x}{(2-x) \sqrt{1-x}}
# Out:
# <details style="margin:2px 0"><summary style="cursor:pointer;color:#888">agent turns &mdash; 6 steps &middot; 6 checked <span style="font-size:90%">(click to expand)</span></summary><div style="margin:4px 0 4px 1em;border-left:2px solid #eee;padding-left:.8em"><div><code>s139#ed777ef [ok] (new chain; no marker) integrate_substitute</code> &nbsp;$\frac{1}{(2-x)\sqrt{1-x}} \;\Longrightarrow\; \int \left(-\frac{2}{1+u^2}\right) \, d u$</div><div><code>s140#decfa9f [ok] integrate_table</code> &nbsp;$\int \left(-\frac{2}{1+u^2}\right) \, d u \;\Longrightarrow\; -2 \arctan\left(u\right) + C$</div><div><code>s141#cf4611c [ok] substitute</code> &nbsp;$-2 \arctan\left(u\right) + C \;\Longrightarrow\; -2 \arctan\left (( \sqrt{1-x}) \right )+C$</div><div><code>s142#ad0ac9a [ok] (new chain; no marker) integrate_definite</code> &nbsp;$\int_{0}^{t} \frac{1}{(2-x)\sqrt{1-x}}\,dx \;\Longrightarrow\; \left(-2 \arctan\left (( \sqrt{1-t}) \right )+C\right) - \left(-2 \arctan\left (( \sqrt{1}) \right )+
# ...

# %%
do! eval \lim _{x \rightarrow 0} x \int_x^1 \frac{\cos t}{t^2} d t
# Out:
# <div><code>s145#e66ed5e [ok] (new chain; no marker) limit_evaluate</code> &nbsp;$\lim_{x\to 0^{+}} x\int_x^1 \frac{\cos t}{t^2}\,dt \;\Longrightarrow\; 1$</div>
# ...

# %%
int! \int_0^{+\infty} \frac{d x}{\operatorname{ch} x}
# Out:
# <details style="margin:2px 0"><summary style="cursor:pointer;color:#888">agent turns &mdash; 6 steps &middot; 6 checked <span style="font-size:90%">(click to expand)</span></summary><div style="margin:4px 0 4px 1em;border-left:2px solid #eee;padding-left:.8em"><div><code>s146#427ac2f [ok] (new chain; no marker) integrate_substitute</code> &nbsp;$\frac{1}{\cosh x} \;\Longrightarrow\; \int \frac{1}{1+u^{2}} \, d u$</div><div><code>s147#50b92e5 [ok] integrate_table</code> &nbsp;$\int \frac{1}{1+u^{2}} \, d u \;\Longrightarrow\; \arctan\left(u\right) + C$</div><div><code>s148#9b9e681 [ok] substitute</code> &nbsp;$\arctan\left(u\right) + C \;\Longrightarrow\; \arctan\left (( \sinh x) \right )+C$</div><div><code>s149#9b330ad [ok] (new chain; no marker) integrate_definite</code> &nbsp;$\int_{0}^{t}\frac{dx}{\cosh x} \;\Longrightarrow\; \left(\arctan\left (( \sinh t) \right )+C\right) - \left(\arctan\left (( \sinh (0)) \right )+C\right)$</div><div style="margin-left:2em;color:#888">assumes $
# ...

# %%
do! eval I_n=\int_0^{+\infty} \frac{d x}{\operatorname{ch}^{n+1} x}
# Out:
# <details style="margin:2px 0"><summary style="cursor:pointer;color:#888">agent turns &mdash; 14 steps &middot; 14 checked <span style="font-size:90%">(click to expand)</span></summary><div style="margin:4px 0 4px 1em;border-left:2px solid #eee;padding-left:.8em"><div><code>s152#cb7b193 [ok] (new chain; no marker) integrate_reduction</code> &nbsp;$\int_0^{+\infty}\frac{dx}{\cosh^{n+1}x}=\frac{n-1}{n}\int_0^{+\infty}\frac{dx}{\cosh^{n-1}x} \;\Longrightarrow\; \int_0^{+\infty}\frac{dx}{\cosh^{n+1}x}=\frac{n-1}{n}\int_0^{+\infty}\frac{dx}{\cosh^{n-1}x}$</div><div style="margin-left:2em;color:#888">assumes assuming $n>1$</div><div style="margin-left:2em;color:#888">assumes both sides read as definitional limits; convergence at sampled parameters is evidence, not proof</div><div><code>s153#8498c1e [ok] (new chain; no marker) integrate_substitute</code> &nbsp;$\frac{1}{\cosh x} \;\Longrightarrow\; \int \frac{1}{1+u^2} \, d u$</div><div><code>s154#ad155c4 [ok] integrate_table</code> &nbsp;$\
# ...

# %%
int! \int_0^{+\infty} \frac{\ln (1+x)}{x^n} d x
# Out:
# <details style="margin:2px 0"><summary style="cursor:pointer;color:#888">agent turns &mdash; 7 steps &middot; 7 checked <span style="font-size:90%">(click to expand)</span></summary><div style="margin:4px 0 4px 1em;border-left:2px solid #eee;padding-left:.8em"><div><code>s166#00bb72c [ok] (new chain; no marker) integrate_power_rule</code> &nbsp;$x^{-n} \;\Longrightarrow\; \frac{x^{(-n)+1}}{(-n)+1} + C$</div><div style="margin-left:2em;color:#888">assumes $-n \ne -1$ (exponent $-1$ is the logarithm case)</div><div style="margin-left:2em;color:#888">assumes $x > 0$</div><div><code>s167#6fb5ac6 [ok] substitute</code> &nbsp;$\frac{x^{(-n)+1}}{(-n)+1} + C \;\Longrightarrow\; \frac {x^{(-n)+1}} {(-n)+1}$</div><div><code>s168#b98aabf [ok] (new chain; no marker) limit_evaluate</code> &nbsp;$\lim_{x \to \infty} (\ln(1+x)) \frac {x^{(-n)+1}} {(-n)+1} \;\Longrightarrow\; 0$</div><div style="margin-left:2em;color:#888">assumes assuming $n > 1$</div><div><code>s169#4fc0610 [ok] (new chain; no mar
# ...
