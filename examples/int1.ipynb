# %%
int! \int \frac {x^2 dx}(1-x^2)^3
# Out:
# <div class="tex2jax_ignore" style="color:#666"><code>s1</code> <em>Try integration by parts with u = x and dv = x / (1 - x^2)^3.</em></div>
# <div><code>s2#3009c34 [ok] integrate_rewrite</code> &nbsp;$\frac{x^{2}}{(1-x^{2})^{3}} \;\Longrightarrow\; \int \left(\frac{1}{(1-x^{2})^{3}}-\frac{1}{(1-x^{2})^{2}}\right) \, d x$</div>
# <div><code>s3#56d3228 [ok] (new chain; no marker) integrate_rewrite</code> &nbsp;$\frac{x^{2}}{(1-x^{2})^{3}} \;\Longrightarrow\; \int \left(\frac{1}{8(1-x)^{3}}+\frac{1}{8(1+x)^{3}}-\frac{1}{16(1-x)^{2}}-\frac{1}{16(1+x)^{2}}-\frac{1}{16(1-x)}-\frac{1}{16(1+x)}\right) \, d x$</div>
# <div><code>s4#2800120 [ok] integrate_linearity</code> &nbsp;$\frac{1}{8(1-x)^{3}}+\frac{1}{8(1+x)^{3}}-\frac{1}{16(1-x)^{2}}-\frac{1}{16(1+x)^{2}}-\frac{1}{16(1-x)}-\frac{1}{16(1+x)} \;\Longrightarrow\; \int \frac {1} {8(1-x)^{3}} \, d x + \int \frac {1} {8(1+x)^{3}} \, d x - \int \frac {1} {16(1-x)^{2}} \, d x - \int \frac {1} {16(1+x)^{2}} \, d x - \int \frac {1} {16(1-x)} \, d x - \int \frac {1} {16(1+x)} \, d x$</div>
# <div><code>s5#cc8ef2e [ok] (new chain; no marker) integrate_substitute</code> &nbsp;$\frac{1}{8(1-x)^{3}} \;\Longrightarrow\; \int \left(-\frac{1}{8u^{3}}\right) \, d u$</div>
# <div><code>s6#9b8d4ce [ok] integrate_power_rule</code> &nbsp;$-\frac{1}{8u^{3}} \;\Longrightarrow\; \frac{\frac {1} {16}}{u^{2}} + C$</div>
# <div><code>s7#5e60372 [ok] substitute</code> &nbsp;$\frac{\frac {1} {16}}{u^{2}} + C \;\Longrightarrow\; \frac {\frac {1} {16}} {u^{2}}$</div>
# <div><code>s8#876817d [ok] substitute</code> &nbsp;$\frac {\frac {1} {16}} {u^{2}} \;\Longrightarrow\; \frac {\frac {1} {16}} {(1-x)^{2}}$</div>
# <div><code>s9#1d30f0c [ok] (new chain; no marker) integrate_substitute</code> &nbsp;$\frac{1}{8(1+x)^{3}} \;\Longrightarrow\; \int \frac{1}{8u^{3}} \, d u$</div>
# <div><code>s10#3cf50a9 [ok] integrate_power_rule</code> &nbsp;$\frac{1}{8u^{3}} \;\Longrightarrow\; -\frac{\frac {1} {16}}{u^{2}} + C$</div>
# <div><code>s11#9ddbdc4 [ok] substitute</code> &nbsp;$-\frac{\frac {1} {16}}{u^{2}} + C \;\Longrightarrow\; - \frac {\frac {1} {16}} {u^{2}}$</div>
# <div><code>s12#34fe25b [ok] substitute</code> &nbsp;$- \frac {\frac {1} {16}} {u^{2}} \;\Longrightarrow\; - \frac {\frac {1} {16}} {(1+x)^{2}}$</div>
# <div><code>s13#a6badb4 [ok] (new chain; no marker) integrate_substitute</code> &nbsp;$\frac{1}{16(1-x)^{2}} \;\Longrightarrow\; \int \left(-\frac{1}{16u^{2}}\right) \, d u$</div>
# <div><code>s14#9b80fe6 [ok] integrate_power_rule</code> &nbsp;$-\frac{1}{16u^{2}} \;\Longrightarrow\; \frac{\frac {1} {16}}{u} + C$</div>
# <div><code>s15#564a5c7 [ok] substitute</code> &nbsp;$\frac{\frac {1} {16}}{u} + C \;\Longrightarrow\; \frac {\frac {1} {16}} {u}$</div>
# <div><code>s16#39ae00c [ok] substitute</code> &nbsp;$\frac {\frac {1} {16}} {u} \;\Longrightarrow\; \frac {\frac {1} {16}} {(1-x)}$</div>
# <div><code>s17#2af2868 [ok] (new chain; no marker) integrate_substitute</code> &nbsp;$\frac{1}{16(1+x)^{2}} \;\Longrightarrow\; \int \frac{1}{16u^{2}} \, d u$</div>
# <div><code>s18#d324643 [ok] integrate_power_rule</code> &nbsp;$\frac{1}{16u^{2}} \;\Longrightarrow\; -\frac{\frac {1} {16}}{u} + C$</div>
# <div><code>s19#04c8b9a [ok] substitute</code> &nbsp;$-\frac{\frac {1} {16}}{u} + C \;\Longrightarrow\; - \frac {\frac {1} {16}} {u}$</div>
# <div><code>s20#ba3bac9 [ok] substitute</code> &nbsp;$- \frac {\frac {1} {16}} {u} \;\Longrightarrow\; - \frac {\frac {1} {16}} {(1+x)}$</div>
# <div><code>s21#5a5eb22 [ok] (new chain; no marker) integrate_substitute</code> &nbsp;$\frac{1}{16(1-x)} \;\Longrightarrow\; \int \left(-\frac{1}{16u}\right) \, d u$</div>
# <div><code>s22#b08e9e3 [ok] integrate_table</code> &nbsp;$-\frac{1}{16u} \;\Longrightarrow\; -\frac {1} {16} \ln\left(u\right) + C$</div><div style="margin-left:2em;color:#888">assumes $u > 0$</div>
# <div><code>s23#2722ab6 [ok] substitute</code> &nbsp;$-\frac {1} {16} \ln\left(u\right) + C \;\Longrightarrow\; - \frac {1} {16}\ln\left (u \right )$</div>
# <div><code>s24#abffb16 [ok] substitute</code> &nbsp;$- \frac {1} {16}\ln\left (u \right ) \;\Longrightarrow\; - \frac {1} {16}\ln\left ((1-x) \right )$</div>
# <div><code>s25#e370b9f [ok] (new chain; no marker) integrate_substitute</code> &nbsp;$\frac{1}{16(1+x)} \;\Longrightarrow\; \int \frac{1}{16u} \, d u$</div>
# <div><code>s26#7e2a097 [ok] integrate_table</code> &nbsp;$\frac{1}{16u} \;\Longrightarrow\; \frac {1} {16} \ln\left(u\right) + C$</div><div style="margin-left:2em;color:#888">assumes $u > 0$</div>
# <div><code>s27#3112a4a [ok] substitute</code> &nbsp;$\frac {1} {16} \ln\left(u\right) + C \;\Longrightarrow\; \frac {1} {16}\ln\left (u \right )$</div>
# <div><code>s28#ca1c32b [ok] substitute</code> &nbsp;$\frac {1} {16}\ln\left (u \right ) \;\Longrightarrow\; \frac {1} {16}\ln\left ((1+x) \right )$</div>
# <div><code>s29#397cfae [ok] (new chain; no marker) integrate_assemble</code> &nbsp;$\frac{1}{8(1-x)^{3}}+\frac{1}{8(1+x)^{3}}-\frac{1}{16(1-x)^{2}}-\frac{1}{16(1+x)^{2}}-\frac{1}{16(1-x)}-\frac{1}{16(1+x)} \;\Longrightarrow\; \left(\frac {\frac {1} {16}} {(1-x)^{2}}\right) + \left(- \frac {\frac {1} {16}} {(1+x)^{2}}\right) - \left(\frac {\frac {1} {16}} {(1-x)}\right) - \left(- \frac {\frac {1} {16}} {(1+x)}\right) - \left(- \frac {1} {16}\ln\left ((1-x) \right )\right) - \left(\frac {1} {16}\ln\left ((1+x) \right )\right) + C$</div>
# <div><code>s30#bdd2687 [ok] expand</code> &nbsp;$( \left ( \frac {\frac {1} {16}} {(1-x)^{2}}\right )+ \left (- \frac {\frac {1} {16}} {(1+x)^{2}}\right )- \left ( \frac {\frac {1} {16}} {(1-x)}\right )- \left (- \frac {\frac {1} {16}} {(1+x)}\right )- \left (- \frac {1} {16}\ln\left ((1-x) \right ) \right )- \left ( \frac {1} {16}\ln\left ((1+x) \right ) \right )+C) \;\Longrightarrow\; \frac {Cx^{4}+ \frac {1} {16}x^{4}\ln\left ((-x+1) \right )- \frac {1} {16}x^{4}\ln\left ((x+1) \right )-2Cx^{2}+ \frac {1} {8}x^{3}- \frac {1} {8}x^{2}\ln\left ((-x+1) \right )+ \frac {1} {8}x^{2}\ln\left ((x+1) \right )+C+ \frac {1} {8}x+ \frac {1} {16}\ln\left ((-x+1) \right )- \frac {1} {16}\ln\left ((x+1) \right )} {x^{4}-2x^{2}+1}$</div><div style="margin-left:2em;color:#888">assumes $(1-x) \ne 0$</div><div style="margin-left:2em;color:#888">assumes $(1+x) \ne 0$</div>
# <div style="color:#888">assumptions: $u > 0$; $(1-x) \ne 0$; $(1+x) \ne 0$</div>
# $\frac {Cx^{4}+ \frac {1} {16}x^{4}\ln\left ((-x+1) \right )- \frac {1} {16}x^{4}\ln\left ((x+1) \right )-2Cx^{2}+ \frac {1} {8}x^{3}- \frac {1} {8}x^{2}\ln\left ((-x+1) \right )+ \frac {1} {8}x^{2}\ln\left ((x+1) \right )+C+ \frac {1} {8}x+ \frac {1} {16}\ln\left ((-x+1) \right )- \frac {1} {16}\ln\left ((x+1) \right )} {x^{4}-2x^{2}+1}$

# %%
simplify! [[1]]
# Out:
# <div><code>s31#078d55e [ok] expand</code> &nbsp;$\frac {Cx^{4}+ \frac {1} {16}x^{4}\ln\left ((-x+1) \right )- \frac {1} {16}x^{4}\ln\left ((x+1) \right )-2Cx^{2}+ \frac {1} {8}x^{3}- \frac {1} {8}x^{2}\ln\left ((-x+1) \right )+ \frac {1} {8}x^{2}\ln\left ((x+1) \right )+C+ \frac {1} {8}x+ \frac {1} {16}\ln\left ((-x+1) \right )- \frac {1} {16}\ln\left ((x+1) \right )} {x^{4}-2x^{2}+1} \;\Longrightarrow\; \frac {Cx^{4}+ \frac {1} {16}x^{4}\ln\left ((-x+1) \right )- \frac {1} {16}x^{4}\ln\left ((x+1) \right )-2Cx^{2}+ \frac {1} {8}x^{3}- \frac {1} {8}x^{2}\ln\left ((-x+1) \right )+ \frac {1} {8}x^{2}\ln\left ((x+1) \right )+C+ \frac {1} {8}x+ \frac {1} {16}\ln\left ((-x+1) \right )- \frac {1} {16}\ln\left ((x+1) \right )} {x^{4}-2x^{2}+1}$</div>
# <div><code>s32#3108fe8 [ok] rewrite_as</code> &nbsp;$\frac {Cx^{4}+ \frac {1} {16}x^{4}\ln\left ((-x+1) \right )- \frac {1} {16}x^{4}\ln\left ((x+1) \right )-2Cx^{2}+ \frac {1} {8}x^{3}- \frac {1} {8}x^{2}\ln\left ((-x+1) \right )+ \frac {1} {8}x^{2}\ln\left ((x+1) \right )+C+ \frac {1} {8}x+ \frac {1} {16}\ln\left ((-x+1) \right )- \frac {1} {16}\ln\left ((x+1) \right )} {x^{4}-2x^{2}+1} \;\Longrightarrow\; C + \frac{1}{16}\ln\left(-x+1\right) - \frac{1}{16}\ln\left(x+1\right) + \frac{\frac{1}{8}x^3 + \frac{1}{8}x}{x^4 - 2x^2 + 1}$</div>
# <div><code>s33#14bbcb7 [ok] rewrite_as</code> &nbsp;$C + \frac{1}{16}\ln\left(-x+1\right) - \frac{1}{16}\ln\left(x+1\right) + \frac{\frac{1}{8}x^3 + \frac{1}{8}x}{x^4 - 2x^2 + 1} \;\Longrightarrow\; C + \frac{1}{16}\ln\left(\frac{1-x}{1+x}\right) + \frac{x(x^2+1)}{8(x^2-1)^2}$</div><div style="margin-left:2em;color:#888">assumes $1+x \ne 0$</div>
# <div style="margin-top:4px"><strong>verified chain</strong> <span style="color:#888">&mdash; rendered from the selected ledger spine</span></div><table style="border-collapse:collapse"><tr><th style="padding:2px 12px 2px 0;text-align:left;border-bottom:1px solid #8884">step</th><th style="padding:2px 12px 2px 0;text-align:left;border-bottom:1px solid #8884">move</th><th style="padding:2px 12px 2px 0;text-align:left;border-bottom:1px solid #8884">result</th><th style="padding:2px 12px 2px 0;text-align:left;border-bottom:1px solid #8884">check</th></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s31</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>expand</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$\frac {Cx^{4}+ \frac {1} {16}x^{4}\ln\left ((-x+1) \right )- \frac {1} {16}x^{4}\ln\left ((x+1) \right )-2Cx^{2}+ \frac {1} {8}x^{3}- \frac {1} {8}x^{2}\ln\left ((-x+1) \right )+ \frac {1} {8}x^{2}\ln\left ((x+1) \right )+C+ \frac {1} {8}x+ \frac {1} {16}\ln\left ((-x+1) \right )- \frac {1} {16}\ln\left ((x+1) \right )} {x^{4}-2x^{2}+1}$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s32</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>rewrite_as</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$C + \frac{1}{16}\ln\left(-x+1\right) - \frac{1}{16}\ln\left(x+1\right) + \frac{\frac{1}{8}x^3 + \frac{1}{8}x}{x^4 - 2x^2 + 1}$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s33</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>rewrite_as</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$C + \frac{1}{16}\ln\left(\frac{1-x}{1+x}\right) + \frac{x(x^2+1)}{8(x^2-1)^2}$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree <span style="color:#888">+1 assum.</span></td></tr></table>
# <div class="tex2jax_ignore"><em>To simplify the given algebraic expression, we group terms with shared factors in the numerator, separate the rational polynomial part from the logarithmic components, combine the logarithms into a single logarithmic ratio, and factor the remaining rational term.
#
# The simplified expression is:
# $$C + \frac{1}{16}\ln\left(\frac{1-x}{1+x}\right) + \frac{x(x^2+1)}{8(x^2-1)^2}$$</em></div>
# <div style="color:#888">assumptions: $u > 0$; $(1-x) \ne 0$; $(1+x) \ne 0$; $1+x \ne 0$</div>
# $C+ \frac {1} {16}\ln\left ( \frac {1-x} {1+x}\right )+ \frac {x(x^{2}+1)} {8(x^{2}-1)^{2}}$

# %%
diff! [x] [[3]]
# Out:
# <div style="color:#b65c00"><code>s34#62687b7 [D!] differentiate</code> &nbsp;$C+ \frac  {{1}} {{16}}\ln\left ( \frac  {{1}-x} {{1}+x}\right )+ \frac  {x(x^{{2}}+{1})} {{8}(x^{{2}}-{1})^{{2}}} \;\Longrightarrow\; \frac {-x^{2}} {x^{6}-3x^{4}+3x^{2}-1}$</div>
# <div><code>s35#fc4cf9a [ok] expand</code> &nbsp;$( \frac {-x^{2}} {x^{6}-3x^{4}+3x^{2}-1}) \;\Longrightarrow\; \frac {-x^{2}} {x^{6}-3x^{4}+3x^{2}-1}$</div>
# $\frac {-x^{2}} {x^{6}-3x^{4}+3x^{2}-1}$

# %%
int! \int \frac {dx} (x^{\frac 1 2} + x^{\frac 1 3})
# Out:
# <div><code>s1#e75af00 [ok] integrate_substitute</code> &nbsp;$\frac{1}{x^{1/2}+x^{1/3}} \;\Longrightarrow\; \int \frac{6u^3}{u+1} \, d u$</div>
# <div><code>s2#bded9a5 [ok] integrate_rewrite</code> &nbsp;$\frac{6u^3}{u+1} \;\Longrightarrow\; \int \left(6u^2 - 6u + 6 - \frac{6}{u+1}\right) \, d u$</div>
# <div><code>s3#2d4a240 [ok] integrate_linearity</code> &nbsp;$6u^2 - 6u + 6 - \frac{6}{u+1} \;\Longrightarrow\; \int 6u^{2} \, d u - \int 6u \, d u + \int 6 \, d u - \int \frac {6} {u+1} \, d u$</div>
# <div><code>s4#d34e65d [ok] (new chain; no marker) integrate_power_rule</code> &nbsp;$6u^2 \;\Longrightarrow\; 2u^{3} + C$</div>
# <div><code>s5#530a970 [ok] (new chain; no marker) integrate_power_rule</code> &nbsp;$6u \;\Longrightarrow\; 3u^{2} + C$</div>
# <div><code>s6#32edfa0 [ok] (new chain; no marker) integrate_power_rule</code> &nbsp;$6 \;\Longrightarrow\; 6u + C$</div>
# <div><code>s7#c0b9d1c [ok] (new chain; no marker) integrate_substitute</code> &nbsp;$\frac{6}{u+1} \;\Longrightarrow\; \int \frac{6}{v} \, d v$</div>
# <div><code>s8#856a97e [ok] integrate_table</code> &nbsp;$\frac{6}{v} \;\Longrightarrow\; 6 \ln\left(v\right) + C$</div><div style="margin-left:2em;color:#888">assumes $v > 0$</div>
# <div><code>s9#d23bfd9 [ok] substitute</code> &nbsp;$6 \ln\left(v\right) + C \;\Longrightarrow\; 6 \ln\left ((u+1) \right )+C$</div>
# <div><code>s10#7cbb449 [ok] (new chain; no marker) substitute</code> &nbsp;$2u^{3} + C \;\Longrightarrow\; 2u^{3}$</div>
# <div><code>s11#d54911a [ok] (new chain; no marker) substitute</code> &nbsp;$6u + C \;\Longrightarrow\; 6u$</div>
# <div><code>s12#7cac21e [ok] (new chain; no marker) substitute</code> &nbsp;$3u^{2} + C \;\Longrightarrow\; 3u^{2}$</div>
# <div><code>s13#684b0ff [ok] (new chain; no marker) substitute</code> &nbsp;$6 \ln\left ((u+1) \right )+C \;\Longrightarrow\; 6 \ln\left ((u+1) \right )$</div>
# <div><code>s14#ebef2cd [ok] (new chain; no marker) integrate_assemble</code> &nbsp;$6u^2 - 6u + 6 - \frac{6}{u+1} \;\Longrightarrow\; \left(2u^{3}\right) - \left(3u^{2}\right) + \left(6u\right) - \left(6 \ln\left ((u+1) \right )\right) + C$</div>
# <div><code>s15#98e4d68 [ok] substitute</code> &nbsp;$\left(2u^{3}\right) - \left(3u^{2}\right) + \left(6u\right) - \left(6 \ln\left ((u+1) \right )\right) + C \;\Longrightarrow\; \left (2(x^{1/6})^{3}\right )- \left (3(x^{1/6})^{2}\right )+ \left (6(x^{1/6}) \right )- \left (6 \ln\left (((x^{1/6})+1) \right ) \right )+C$</div>
# <div><code>s16#dfd9997 [ok] expand</code> &nbsp;$\left (2(x^{1/6})^{3}\right )- \left (3(x^{1/6})^{2}\right )+ \left (6(x^{1/6}) \right )- \left (6 \ln\left (((x^{1/6})+1) \right ) \right )+C \;\Longrightarrow\; 2x^{\frac {1} {2}}-3x^{\frac {1} {3}}+C+6x^{\frac {1} {6}}-6 \ln\left ((x^{\frac {1} {6}}+1) \right )$</div><div style="margin-left:2em;color:#888">assumes $x > 0$</div>
# <div><code>s17#336901f [ok] expand</code> &nbsp;$(2x^{1/2}-3x^{1/3}+6x^{1/6}-6 \ln\left (x^{1/6}+1 \right )+C) \;\Longrightarrow\; 2x^{\frac {1} {2}}-3x^{\frac {1} {3}}+C+6x^{\frac {1} {6}}-6 \ln\left (x^{\frac {1} {6}}+1 \right )$</div><div style="margin-left:2em;color:#888">assumes $x > 0$</div>
# <div style="color:#888">assumptions: $x > 0$</div>
# $2x^{\frac {1} {2}}-3x^{\frac {1} {3}}+C+6x^{\frac {1} {6}}-6 \ln\left (x^{\frac {1} {6}}+1 \right )$

# %%
int! \int \frac{d x}{2 \sin x-\cos x+5}
# Out:
# <div><code>s1#dbc1894 [ok] integrate_substitute</code> &nbsp;$\frac{1}{2 \sin x - \cos x + 5} \;\Longrightarrow\; \int \frac{1}{3 t^2 + 2 t + 2} \, d t$</div>
# <div><code>s2#a210a73 [ok] integrate_rewrite</code> &nbsp;$\frac{1}{3 t^2 + 2 t + 2} \;\Longrightarrow\; \int \frac{1}{3(t + \frac{1}{3})^2 + \frac{5}{3}} \, d t$</div>
# <div><code>s3#90dd9c3 [ok] integrate_substitute</code> &nbsp;$\frac{1}{3(t + \frac{1}{3})^2 + \frac{5}{3}} \;\Longrightarrow\; \int \frac{1}{3 u^2 + \frac{5}{3}} \, d u$</div>
# <div><code>s4#7453809 [ok] integrate_table</code> &nbsp;$\frac{1}{3 u^2 + \frac{5}{3}} \;\Longrightarrow\; \frac{1}{\sqrt{5}} \arctan\left(\frac{3}{\sqrt{5}} u\right) + C$</div>
# <div><code>s5#e40eb40 [ok] substitute</code> &nbsp;$\frac{1}{\sqrt{5}} \arctan\left(\frac{3}{\sqrt{5}} u\right) + C \;\Longrightarrow\; \frac {1} {\sqrt{5}}\arctan\left ( \frac {3} {\sqrt{5}}(t+ \frac {1} {3}) \right )+C$</div>
# <div><code>s6#052e473 [ok] substitute</code> &nbsp;$\frac {1} {\sqrt{5}}\arctan\left ( \frac {3} {\sqrt{5}}(t+ \frac {1} {3}) \right )+C \;\Longrightarrow\; \frac {1} {\sqrt{5}}\arctan\left ( \frac {3} {\sqrt{5}}(( \tan ( \frac {x} {2}))+ \frac {1} {3}) \right )+C$</div>
# <div><code>s7#c16b028 [ok] expand</code> &nbsp;$( \frac {1} {\sqrt{5}}\arctan\left ( \frac {3} {\sqrt{5}}( \tan ( \frac {x} {2})+ \frac {1} {3}) \right )+C) \;\Longrightarrow\; \frac {C \sqrt{5}+ \arctan\left ( \frac {3} {\sqrt{5}}( \tan ( \frac {1} {2}x)+ \frac {1} {3}) \right )} {\sqrt{5}}$</div>
# $\frac {C \sqrt{5}+ \arctan\left ( \frac {3} {\sqrt{5}}( \tan ( \frac {1} {2}x)+ \frac {1} {3}) \right )} {\sqrt{5}}$

# %%
int! \int \frac{\sin x d x}{\sin ^3 x+\cos ^3 x}
# Out:
# <div><code>s8#b476d54 [ok] (new chain; no marker) integrate_substitute</code> &nbsp;$\frac{\sin x}{\sin^3 x + \cos^3 x} \;\Longrightarrow\; \int \frac{u}{u^3 + 1} \, d u$</div>
# <div><code>s9#57ed4fa [ok] integrate_rewrite</code> &nbsp;$\int \frac{u}{u^3 + 1} \, d u \;\Longrightarrow\; \int \left(-\frac{1}{3(u+1)} + \frac{u+1}{3(u^2 - u + 1)}\right) \, d u$</div>
# <div><code>s10#4873116 [ok] integrate_linearity</code> &nbsp;$\int \left(-\frac{1}{3(u+1)} + \frac{u+1}{3(u^2 - u + 1)}\right) \, d u \;\Longrightarrow\; -\int \frac {1} {3(u+1)} \, d u + \int \frac {u+1} {3(u^{2}-u+1)} \, d u$</div>
# <div><code>s11#df4cdab [ok] (new chain; no marker) integrate_substitute</code> &nbsp;$\int \frac {1} {3(u+1)} \, d u \;\Longrightarrow\; \int \frac{1}{3v} \, d v$</div>
# <div><code>s12#98e8167 [ok] integrate_table</code> &nbsp;$\int \frac{1}{3v} \, d v \;\Longrightarrow\; \frac {1} {3} \ln\left(v\right) + C$</div><div style="margin-left:2em;color:#888">assumes $v > 0$</div>
# <div><code>s13#3ca28ef [ok] substitute</code> &nbsp;$\frac {1} {3} \ln\left(v\right) + C \;\Longrightarrow\; \frac {1} {3}\ln\left (v \right )$</div>
# <div><code>s14#f1cdf4d [ok] substitute</code> &nbsp;$\frac {1} {3}\ln\left (v \right ) \;\Longrightarrow\; \frac {1} {3}\ln\left ((u+1) \right )$</div>
# <div><code>s15#0b58dbd [ok] (new chain; no marker) integrate_rewrite</code> &nbsp;$\int \frac {u+1} {3(u^{2}-u+1)} \, d u \;\Longrightarrow\; \int \left(\frac{2u-1}{6(u^2-u+1)} + \frac{1}{2(u^2-u+1)}\right) \, d u$</div>
# <div><code>s16#0c9705f [ok] integrate_linearity</code> &nbsp;$\int \left(\frac{2u-1}{6(u^2-u+1)} + \frac{1}{2(u^2-u+1)}\right) \, d u \;\Longrightarrow\; \int \frac {2u-1} {6(u^{2}-u+1)} \, d u + \int \frac {1} {2(u^{2}-u+1)} \, d u$</div>
# <div><code>s17#0720859 [ok] (new chain; no marker) integrate_substitute</code> &nbsp;$\int \frac {2u-1} {6(u^{2}-u+1)} \, d u \;\Longrightarrow\; \int \frac{1}{6w} \, d w$</div>
# <div><code>s18#1cbcdd2 [ok] integrate_table</code> &nbsp;$\int \frac{1}{6w} \, d w \;\Longrightarrow\; \frac {1} {6} \ln\left(w\right) + C$</div><div style="margin-left:2em;color:#888">assumes $w > 0$</div>
# <div><code>s19#8ae7ced [ok] substitute</code> &nbsp;$\frac {1} {6} \ln\left(w\right) + C \;\Longrightarrow\; \frac {1} {6}\ln\left (w \right )$</div>
# <div><code>s20#4fe1b44 [ok] substitute</code> &nbsp;$\frac {1} {6}\ln\left (w \right ) \;\Longrightarrow\; \frac {1} {6}\ln\left ((u^{2}-u+1) \right )$</div>
# <div><code>s21#da62a9f [ok] (new chain; no marker) integrate_rewrite</code> &nbsp;$\int \frac {1} {2(u^{2}-u+1)} \, d u \;\Longrightarrow\; \int \frac{1}{2\left(\left(u-\frac{1}{2}\right)^2 + \frac{3}{4}\right)} \, d u$</div>
# <div><code>s22#2df18f8 [ok] integrate_substitute</code> &nbsp;$\int \frac{1}{2\left(\left(u-\frac{1}{2}\right)^2 + \frac{3}{4}\right)} \, d u \;\Longrightarrow\; \int \frac{1}{2z^2 + \frac{3}{2}} \, d z$</div>
# <div><code>s23#a7a0c84 [ok] integrate_table</code> &nbsp;$\int \frac{1}{2z^2 + \frac{3}{2}} \, d z \;\Longrightarrow\; \frac{1}{\sqrt{3}} \arctan\left(\frac{2}{\sqrt{3}} z\right) + C$</div>
# <div><code>s24#9ce4b71 [ok] substitute</code> &nbsp;$\frac{1}{\sqrt{3}} \arctan\left(\frac{2}{\sqrt{3}} z\right) + C \;\Longrightarrow\; \frac {1} {\sqrt{3}}\arctan\left ( \frac {2} {\sqrt{3}}z \right )$</div>
# <div><code>s25#a5c78bd [ok] substitute</code> &nbsp;$\frac {1} {\sqrt{3}}\arctan\left ( \frac {2} {\sqrt{3}}z \right ) \;\Longrightarrow\; \frac {1} {\sqrt{3}}\arctan\left ( \frac {2} {\sqrt{3}}(u- \frac {1} {2}) \right )$</div>
# <div><code>s26#95c587b [ok] (new chain; no marker) integrate_assemble</code> &nbsp;$\int \left(\frac{2u-1}{6(u^2-u+1)} + \frac{1}{2(u^2-u+1)}\right) \, d u \;\Longrightarrow\; \left(\frac {1} {6}\ln\left ((u^{2}-u+1) \right )\right) + \left(\frac {1} {\sqrt{3}}\arctan\left ( \frac {2} {\sqrt{3}}(u- \frac {1} {2}) \right )\right) + C$</div>
# <div><code>s27#3e84035 [ok] substitute</code> &nbsp;$\left(\frac {1} {6}\ln\left ((u^{2}-u+1) \right )\right) + \left(\frac {1} {\sqrt{3}}\arctan\left ( \frac {2} {\sqrt{3}}(u- \frac {1} {2}) \right )\right) + C \;\Longrightarrow\; \left ( \frac {1} {6}\ln\left ((u^{2}-u+1) \right ) \right )+ \left ( \frac {1} {\sqrt{3}}\arctan\left ( \frac {2} {\sqrt{3}}(u- \frac {1} {2}) \right ) \right )$</div>
# <div><code>s28#878aea2 [ok] (new chain; no marker) integrate_assemble</code> &nbsp;$\int \left(-\frac{1}{3(u+1)} + \frac{u+1}{3(u^2 - u + 1)}\right) \, d u \;\Longrightarrow\; -\left(\frac {1} {3}\ln\left ((u+1) \right )\right) + \left(\left ( \frac {1} {6}\ln\left ((u^{2}-u+1) \right ) \right )+ \left ( \frac {1} {\sqrt{3}}\arctan\left ( \frac {2} {\sqrt{3}}(u- \frac {1} {2}) \right ) \right )\right) + C$</div>
# <div><code>s29#2f6a414 [ok] substitute</code> &nbsp;$-\left(\frac {1} {3}\ln\left ((u+1) \right )\right) + \left(\left ( \frac {1} {6}\ln\left ((u^{2}-u+1) \right ) \right )+ \left ( \frac {1} {\sqrt{3}}\arctan\left ( \frac {2} {\sqrt{3}}(u- \frac {1} {2}) \right ) \right )\right) + C \;\Longrightarrow\; - \left ( \frac {1} {3}\ln\left ((( \tan x)+1) \right ) \right )+ \left ( \left ( \frac {1} {6}\ln\left ((( \tan x)^{2}-( \tan x)+1) \right ) \right )+ \left ( \frac {1} {\sqrt{3}}\arctan\left ( \frac {2} {\sqrt{3}}(( \tan x)- \frac {1} {2}) \right ) \right ) \right )+C$</div>
# <div><code>s30#fde4304 [ok] expand</code> &nbsp;$(- \left ( \frac {1} {3}\ln\left ((( \tan x)+1) \right ) \right )+ \left ( \left ( \frac {1} {6}\ln\left ((( \tan x)^{2}-( \tan x)+1) \right ) \right )+ \left ( \frac {1} {\sqrt{3}}\arctan\left ( \frac {2} {\sqrt{3}}(( \tan x)- \frac {1} {2}) \right ) \right ) \right )+C) \;\Longrightarrow\; \frac {C \sqrt{3}- \frac {1} {3}( \ln\left ((( \tan x)+1) \right )) \sqrt{3}+ \frac {1} {6}( \ln\left ((( \tan x)^{2}-( \tan x)+1) \right )) \sqrt{3}+ \arctan\left ( \frac {2} {\sqrt{3}}(( \tan x)- \frac {1} {2}) \right )} {\sqrt{3}}$</div>
# <div style="color:#888">assumptions: $v > 0$; $w > 0$</div>
# $\frac {C \sqrt{3}- \frac {1} {3}( \ln\left ((( \tan x)+1) \right )) \sqrt{3}+ \frac {1} {6}( \ln\left ((( \tan x)^{2}-( \tan x)+1) \right )) \sqrt{3}+ \arctan\left ( \frac {2} {\sqrt{3}}(( \tan x)- \frac {1} {2}) \right )} {\sqrt{3}}$

# %%
do! prove [[2]] is \int \frac{\sin x d x}{\sin ^3 x+\cos ^3 x}
# Out:
# <div style="color:#b65c00"><code>s33#50164ac [D!] (new chain; no marker) differentiate</code> &nbsp;$\frac {C \sqrt{3}- \frac {1} {3}( \ln\left ((( \tan x)+1) \right )) \sqrt{3}+ \frac {1} {6}( \ln\left ((( \tan x)^{2}-( \tan x)+1) \right )) \sqrt{3}+ \arctan\left ( \frac {2} {\sqrt{3}}(( \tan x)- \frac {1} {2}) \right )} {\sqrt{3}} \;\Longrightarrow\; \frac {\frac {1} {2}( \sqrt{\left (3 \right )})^{2}\tan\left (x \right )+4 \tan^{3}\left (x \right )- \frac {1} {2}( \sqrt{\left (3 \right )})^{2}-4 \tan^{2}\left (x \right )+ \frac {5} {2}\tan\left (x \right )+ \frac {3} {2}} {( \sqrt{\left (3 \right )})^{2}\cos^{2}\left (x \right ) \tan^{3}\left (x \right )+4 \cos^{2}\left (x \right ) \tan^{5}\left (x \right )-4 \cos^{2}\left (x \right ) \tan^{4}\left (x \right )+ \cos^{2}\left (x \right ) \tan^{3}\left (x \right )+( \sqrt{\left (3 \right )})^{2}\cos^{2}\left (x \right )+4 \cos^{2}\left (x \right ) \tan^{2}\left (x \right )-4 \cos^{2}\left (x \right ) \tan\left (x \right )+ \cos^{2}\left (x \right )}$</div>
# <div><code>s34#f7f009a [ok] integrate_substitute</code> &nbsp;$\frac{\sin x}{\sin ^3 x+\cos ^3 x} \;\Longrightarrow\; \int \frac{u}{u^3+1} \, d u$</div>
# <div><code>s35#997aac9 [ok] integrate_rewrite</code> &nbsp;$\int \frac{u}{u^3+1} \, d u \;\Longrightarrow\; \int \left(-\frac{1}{3}\frac{1}{u+1} + \frac{1}{3}\frac{u+1}{u^2-u+1}\right) \, d u$</div>
# <div><code>s36#af54113 [ok] integrate_linearity</code> &nbsp;$\int \left(-\frac{1}{3}\frac{1}{u+1} + \frac{1}{3}\frac{u+1}{u^2-u+1}\right) \, d u \;\Longrightarrow\; -\int \frac {1} {3}\frac {1} {u+1} \, d u + \int \frac {1} {3}\frac {u+1} {u^{2}-u+1} \, d u$</div>
# <div><code>s37#78964da [ok] (new chain; no marker) integrate_substitute</code> &nbsp;$\int \frac {1} {3}\frac {1} {u+1} \, d u \;\Longrightarrow\; \int \frac{1}{3v} \, d v$</div>
# <div><code>s38#98e8167 [ok] integrate_table</code> &nbsp;$\int \frac{1}{3v} \, d v \;\Longrightarrow\; \frac {1} {3} \ln\left(v\right) + C$</div><div style="margin-left:2em;color:#888">assumes $v > 0$</div>
# <div><code>s39#3ca28ef [ok] substitute</code> &nbsp;$\frac {1} {3} \ln\left(v\right) + C \;\Longrightarrow\; \frac {1} {3}\ln\left (v \right )$</div>
# <div><code>s40#f1cdf4d [ok] substitute</code> &nbsp;$\frac {1} {3}\ln\left (v \right ) \;\Longrightarrow\; \frac {1} {3}\ln\left ((u+1) \right )$</div>
# <div><code>s41#3684a74 [ok] (new chain; no marker) integrate_rewrite</code> &nbsp;$\int \frac {1} {3}\frac {u+1} {u^{2}-u+1} \, d u \;\Longrightarrow\; \int \left(\frac{1}{6} \frac{2u-1}{u^2-u+1} + \frac{1}{2} \frac{1}{u^2-u+1}\right) \, d u$</div>
# <div><code>s42#a4970ea [ok] integrate_linearity</code> &nbsp;$\int \left(\frac{1}{6} \frac{2u-1}{u^2-u+1} + \frac{1}{2} \frac{1}{u^2-u+1}\right) \, d u \;\Longrightarrow\; \int \frac {1} {6}\frac {2u-1} {u^{2}-u+1} \, d u + \int \frac {1} {2}\frac {1} {u^{2}-u+1} \, d u$</div>
# <div><code>s43#b9b4e21 [ok] (new chain; no marker) integrate_substitute</code> &nbsp;$\int \frac {1} {6}\frac {2u-1} {u^{2}-u+1} \, d u \;\Longrightarrow\; \int \frac{1}{6w} \, d w$</div>
# <div><code>s44#1cbcdd2 [ok] integrate_table</code> &nbsp;$\int \frac{1}{6w} \, d w \;\Longrightarrow\; \frac {1} {6} \ln\left(w\right) + C$</div><div style="margin-left:2em;color:#888">assumes $w > 0$</div>
# <div><code>s45#8ae7ced [ok] substitute</code> &nbsp;$\frac {1} {6} \ln\left(w\right) + C \;\Longrightarrow\; \frac {1} {6}\ln\left (w \right )$</div>
# <div><code>s46#4fe1b44 [ok] substitute</code> &nbsp;$\frac {1} {6}\ln\left (w \right ) \;\Longrightarrow\; \frac {1} {6}\ln\left ((u^{2}-u+1) \right )$</div>
# <div><code>s47#b29d36a [ok] (new chain; no marker) integrate_rewrite</code> &nbsp;$\int \frac {1} {2}\frac {1} {u^{2}-u+1} \, d u \;\Longrightarrow\; \int \frac{1}{2}\frac{1}{(u-1/2)^2 + 3/4} \, d u$</div>
# <div><code>s48#76616d6 [ok] integrate_substitute</code> &nbsp;$\int \frac{1}{2}\frac{1}{(u-1/2)^2 + 3/4} \, d u \;\Longrightarrow\; \int \frac{1}{2}\frac{1}{z^2 + 3/4} \, d z$</div>
# <div><code>s49#164bd89 [ok] integrate_table</code> &nbsp;$\int \frac{1}{2}\frac{1}{z^2 + 3/4} \, d z \;\Longrightarrow\; \frac{1}{\sqrt{3}} \arctan\left(\frac{2}{\sqrt{3}} z\right) + C$</div>
# <div><code>s50#9ce4b71 [ok] substitute</code> &nbsp;$\frac{1}{\sqrt{3}} \arctan\left(\frac{2}{\sqrt{3}} z\right) + C \;\Longrightarrow\; \frac {1} {\sqrt{3}}\arctan\left ( \frac {2} {\sqrt{3}}z \right )$</div>
# <div><code>s51#0e6ee4b [ok] substitute</code> &nbsp;$\frac {1} {\sqrt{3}}\arctan\left ( \frac {2} {\sqrt{3}}z \right ) \;\Longrightarrow\; \frac {1} {\sqrt{3}}\arctan\left ( \frac {2} {\sqrt{3}}(u-1/2) \right )$</div>
# <div><code>s52#5845044 [ok] (new chain; no marker) integrate_assemble</code> &nbsp;$\int \left(\frac{1}{6} \frac{2u-1}{u^2-u+1} + \frac{1}{2} \frac{1}{u^2-u+1}\right) \, d u \;\Longrightarrow\; \left(\frac {1} {6}\ln\left ((u^{2}-u+1) \right )\right) + \left(\frac {1} {\sqrt{3}}\arctan\left ( \frac {2} {\sqrt{3}}(u-1/2) \right )\right) + C$</div>
# <div><code>s53#a2748ad [ok] substitute</code> &nbsp;$\left(\frac {1} {6}\ln\left ((u^{2}-u+1) \right )\right) + \left(\frac {1} {\sqrt{3}}\arctan\left ( \frac {2} {\sqrt{3}}(u-1/2) \right )\right) + C \;\Longrightarrow\; \left ( \frac {1} {6}\ln\left ((u^{2}-u+1) \right ) \right )+ \left ( \frac {1} {\sqrt{3}}\arctan\left ( \frac {2} {\sqrt{3}}(u-1/2) \right ) \right )$</div>
# <div><code>s54#c6b4486 [ok] (new chain; no marker) integrate_assemble</code> &nbsp;$\int \left(-\frac{1}{3}\frac{1}{u+1} + \frac{1}{3}\frac{u+1}{u^2-u+1}\right) \, d u \;\Longrightarrow\; -\left(\frac {1} {3}\ln\left ((u+1) \right )\right) + \left(\left ( \frac {1} {6}\ln\left ((u^{2}-u+1) \right ) \right )+ \left ( \frac {1} {\sqrt{3}}\arctan\left ( \frac {2} {\sqrt{3}}(u-1/2) \right ) \right )\right) + C$</div>
# <div><code>s55#0b7e304 [ok] substitute</code> &nbsp;$-\left(\frac {1} {3}\ln\left ((u+1) \right )\right) + \left(\left ( \frac {1} {6}\ln\left ((u^{2}-u+1) \right ) \right )+ \left ( \frac {1} {\sqrt{3}}\arctan\left ( \frac {2} {\sqrt{3}}(u-1/2) \right ) \right )\right) + C \;\Longrightarrow\; - \left ( \frac {1} {3}\ln\left ((( \tan x)+1) \right ) \right )+ \left ( \left ( \frac {1} {6}\ln\left ((( \tan x)^{2}-( \tan x)+1) \right ) \right )+ \left ( \frac {1} {\sqrt{3}}\arctan\left ( \frac {2} {\sqrt{3}}(( \tan x)-1/2) \right ) \right ) \right )+C$</div>
# <div style="margin-top:4px"><strong>verified chain</strong> <span style="color:#888">&mdash; rendered from the selected ledger spine</span></div><table style="border-collapse:collapse"><tr><th style="padding:2px 12px 2px 0;text-align:left;border-bottom:1px solid #8884">step</th><th style="padding:2px 12px 2px 0;text-align:left;border-bottom:1px solid #8884">move</th><th style="padding:2px 12px 2px 0;text-align:left;border-bottom:1px solid #8884">result</th><th style="padding:2px 12px 2px 0;text-align:left;border-bottom:1px solid #8884">check</th></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s33</code><div class="tex2jax_ignore" style="color:#888;font-size:85%">new chain; no marker</div></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>differentiate</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$\frac {\frac {1} {2}( \sqrt{\left (3 \right )})^{2}\tan\left (x \right )+4 \tan^{3}\left (x \right )- \frac {1} {2}( \sqrt{\left (3 \right )})^{2}-4 \tan^{2}\left (x \right )+ \frac {5} {2}\tan\left (x \right )+ \frac {3} {2}} {( \sqrt{\left (3 \right )})^{2}\cos^{2}\left (x \right ) \tan^{3}\left (x \right )+4 \cos^{2}\left (x \right ) \tan^{5}\left (x \right )-4 \cos^{2}\left (x \right ) \tan^{4}\left (x \right )+ \cos^{2}\left (x \right ) \tan^{3}\left (x \right )+( \sqrt{\left (3 \right )})^{2}\cos^{2}\left (x \right )+4 \cos^{2}\left (x \right ) \tan^{2}\left (x \right )-4 \cos^{2}\left (x \right ) \tan\left (x \right )+ \cos^{2}\left (x \right )}$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#b65c00">domain-differs</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s34</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>integrate_substitute</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$\int \frac{u}{u^3+1} \, d u$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s35</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>integrate_rewrite</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$\int \left(-\frac{1}{3}\frac{1}{u+1} + \frac{1}{3}\frac{u+1}{u^2-u+1}\right) \, d u$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s36</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>integrate_linearity</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$-\int \frac {1} {3}\frac {1} {u+1} \, d u + \int \frac {1} {3}\frac {u+1} {u^{2}-u+1} \, d u$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">exact</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s37</code><div class="tex2jax_ignore" style="color:#888;font-size:85%">new chain; no marker</div></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>integrate_substitute</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$\int \frac{1}{3v} \, d v$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s38</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>integrate_table</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$\frac {1} {3} \ln\left(v\right) + C$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree <span style="color:#888">+1 assum.</span></td></tr><tr><td style="padding:2px 12px 2px 0;t ...
# <div class="tex2jax_ignore"><em>The antiderivative of $\int \frac{\sin x d x}{\sin ^3 x+\cos ^3 x}$ is derived via the substitution $u = \tan x$, partial fraction decomposition, and standard integral integration rules, yielding the given candidate expression.</em></div>
# <div style="color:#888">assumptions: $v > 0$; $w > 0$</div>
# $- \left ( \frac {1} {3}\ln\left ((( \tan x)+1) \right ) \right )+ \left ( \left ( \frac {1} {6}\ln\left ((( \tan x)^{2}-( \tan x)+1) \right ) \right )+ \left ( \frac {1} {\sqrt{3}}\arctan\left ( \frac {2} {\sqrt{3}}(( \tan x)-1/2) \right ) \right ) \right )+C$

# %%
do! prove \begin{aligned}
& \int \frac{d x}{(a+b \cos x)^n}=\frac{A \sin x}{(a+b \cos x)^{n-1}}+ \\
& +B \int \frac{d x}{(a+b \cos x)^{n-1}}+C \int \frac{d x}{(a+b \cos x)^{n-2}}(|a| \neq|b|)
\end{aligned} if n > 1. Find A,B and C
# Out:
# <div><code>s1#779561a [ok] apply_both_sides * 1</code> &nbsp;$A = -\frac{b}{(n-1)(a^2-b^2)} \;\Longrightarrow\; A \cdot \left(1\right) = \left(- \frac {b} {(n-1)(a^{2}-b^{2})}\right) \cdot \left(1\right)$</div>
# <div><code>s2#5d9e80b [ok] expand</code> &nbsp;$A \cdot \left(1\right) = \left(- \frac {b} {(n-1)(a^{2}-b^{2})}\right) \cdot \left(1\right) \;\Longrightarrow\; A = \frac {-b} {a^{2}n-b^{2}n-a^{2}+b^{2}}$</div>
# <div><code>s3#5092805 [ok] apply_both_sides * 1</code> &nbsp;$A = \frac{-b}{(n-1)(a^2-b^2)} \;\Longrightarrow\; A \cdot \left(1\right) = \frac {-b} {(n-1)(a^{2}-b^{2})} \cdot \left(1\right)$</div>
# <div><code>s4#42ff01d [ok] expand</code> &nbsp;$A \cdot \left(1\right) = \frac {-b} {(n-1)(a^{2}-b^{2})} \cdot \left(1\right) \;\Longrightarrow\; A = \frac {-b} {a^{2}n-b^{2}n-a^{2}+b^{2}}$</div>
# <div><code>s5#7774e9c [ok] (new chain; no marker) apply_both_sides * 1</code> &nbsp;$B = \frac{a(2n-3)}{(n-1)(a^2-b^2)} \;\Longrightarrow\; B \cdot \left(1\right) = \frac {a(2n-3)} {(n-1)(a^{2}-b^{2})} \cdot \left(1\right)$</div>
# <div><code>s6#99355df [ok] expand</code> &nbsp;$B \cdot \left(1\right) = \frac {a(2n-3)} {(n-1)(a^{2}-b^{2})} \cdot \left(1\right) \;\Longrightarrow\; B = \frac {2an-3a} {a^{2}n-b^{2}n-a^{2}+b^{2}}$</div>
# <div><code>s7#e2e1465 [ok] (new chain; no marker) apply_both_sides * 1</code> &nbsp;$C = \frac{-(n-2)}{(n-1)(a^2-b^2)} \;\Longrightarrow\; C \cdot \left(1\right) = \frac {-(n-2)} {(n-1)(a^{2}-b^{2})} \cdot \left(1\right)$</div>
# <div><code>s8#c0b41e6 [ok] expand</code> &nbsp;$C \cdot \left(1\right) = \frac {-(n-2)} {(n-1)(a^{2}-b^{2})} \cdot \left(1\right) \;\Longrightarrow\; C = \frac {-n+2} {a^{2}n-b^{2}n-a^{2}+b^{2}}$</div>
# <div><code>s9#1faa583 [ok] (new chain; no marker) system_assemble</code> &nbsp;$A = \frac{-b}{(n-1)(a^2-b^2)}, B = \frac{a(2n-3)}{(n-1)(a^2-b^2)}, C = \frac{-(n-2)}{(n-1)(a^2-b^2)} \;\Longrightarrow\; A= \frac {-b} {a^{2}n-b^{2}n-a^{2}+b^{2}},B= \frac {2an-3a} {a^{2}n-b^{2}n-a^{2}+b^{2}},C= \frac {-n+2} {a^{2}n-b^{2}n-a^{2}+b^{2}}$</div>
# <div style="margin-top:4px"><strong>verified chain</strong> <span style="color:#888">&mdash; rendered from the selected ledger spine</span></div><table style="border-collapse:collapse"><tr><th style="padding:2px 12px 2px 0;text-align:left;border-bottom:1px solid #8884">step</th><th style="padding:2px 12px 2px 0;text-align:left;border-bottom:1px solid #8884">move</th><th style="padding:2px 12px 2px 0;text-align:left;border-bottom:1px solid #8884">result</th><th style="padding:2px 12px 2px 0;text-align:left;border-bottom:1px solid #8884">check</th></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s1</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>apply_both_sides * 1</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$A \cdot \left(1\right) = \left(- \frac {b} {(n-1)(a^{2}-b^{2})}\right) \cdot \left(1\right)$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s2</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>expand</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$A = \frac {-b} {a^{2}n-b^{2}n-a^{2}+b^{2}}$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s3</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>apply_both_sides * 1</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$A \cdot \left(1\right) = \frac {-b} {(n-1)(a^{2}-b^{2})} \cdot \left(1\right)$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s4</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>expand</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$A = \frac {-b} {a^{2}n-b^{2}n-a^{2}+b^{2}}$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s5</code><div class="tex2jax_ignore" style="color:#888;font-size:85%">new chain; no marker</div></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>apply_both_sides * 1</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$B \cdot \left(1\right) = \frac {a(2n-3)} {(n-1)(a^{2}-b^{2})} \cdot \left(1\right)$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s6</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>expand</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$B = \frac {2an-3a} {a^{2}n-b^{2}n-a^{2}+b^{2}}$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s7</code><div class="tex2jax_ignore" style="color:#888;font-size:85%">new chain; no marker</div></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>apply_both_sides * 1</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$C \cdot \left(1\right) = \frac {-(n-2)} {(n-1)(a^{2}-b^{2})} \cdot \left(1\right)$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s8</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>expand</code></td><td style="paddi ...
# $A= \frac {-b} {a^{2}n-b^{2}n-a^{2}+b^{2}},B= \frac {2an-3a} {a^{2}n-b^{2}n-a^{2}+b^{2}},C= \frac {-n+2} {a^{2}n-b^{2}n-a^{2}+b^{2}}$
