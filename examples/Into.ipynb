# %%
do! differentiate x^3−3x, find where the derivative is zero, plot with those points marked
# Out:
# <div style="margin-top:4px"><strong>verified chain</strong> <span style="color:#888">&mdash; rendered from the selected ledger spine</span></div><table style="border-collapse:collapse"><tr><th style="padding:2px 12px 2px 0;text-align:left;border-bottom:1px solid #8884">step</th><th style="padding:2px 12px 2px 0;text-align:left;border-bottom:1px solid #8884">move</th><th style="padding:2px 12px 2px 0;text-align:left;border-bottom:1px solid #8884">result</th><th style="padding:2px 12px 2px 0;text-align:left;border-bottom:1px solid #8884">check</th></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s23</code><div class="tex2jax_ignore" style="color:#888;font-size:85%">new chain; no marker</div></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>differentiate</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$3x^{2}-3$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s24</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>quadratic_roots</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$x=-1 \lor x=1$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s25</code><div class="tex2jax_ignore" style="color:#888;font-size:85%">new chain; no marker</div></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>substitute</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$(-1)^{3}-3(-1)$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s26</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>evaluate</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$2$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s27</code><div class="tex2jax_ignore" style="color:#888;font-size:85%">new chain; no marker</div></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>substitute</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$(1)^{3}-3(1)$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s28</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>evaluate</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$-2$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s29</code><div class="tex2jax_ignore" style="color:#888;font-size:85%">new chain; no marker</div></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>points_assemble</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$\{(-1,2),(1,-2)\}$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree</td></tr></table>
# <div><img src="data:image/png;base64,..." style="max-width:640px"/></div><div style="color:#888"><em>Illustration of $f(x)=x^3-3x$ with the points where its derivative is zero marked.</em> &mdash; illustration, not machine-checked</div>
# <div class="tex2jax_ignore"><em>Verified result and marked points are shown in the plot.</em></div>
# <div style="color:#888">rests on 1 stated premise, not derived here: \(x^3-3x\)</div>
# $\{(-1,2),(1,-2)\}$

# %%
do! draw an example of the commutative diagram
# Out:
# <div class="tex2jax_ignore" style="max-width:640px;overflow-x:auto"><svg xmlns="http://www.w3.org/2000/svg" width="94.221" height="81.663" viewBox="-72 -72 70.666 61.247"><defs><style type="text/css">@font-face{font-family:"cmmi10";src:url(data:font/ttf;base64,...) format("truetype");}@font-face{font-family:"cmmi7";src:url(data:font/ttf;base64,...) format("truetype");}</style></defs><g stroke="#000" stroke-miterlimit="10" stroke-width=".4"><g stroke="none"><text x="-28.791" y="-83.035" stroke="none" font-family="cmmi10" font-size="10" transform="translate(-38.57 23.993)">A</text><text x="24.03" y="-83.035" stroke="none" font-family="cmmi10" font-size="10" transform="translate(-38.864 23.993)">B</text><text x="-28.791" y="-41.883" stroke="none" font-family="cmmi10" font-size="10" transform="translate(-38.752 23.993)">C</text><text x="24.03" y="-41.883" stroke="none" font-family="cmmi10" font-size="10" transform="translate(-39.1 23.993)">D</text></g><path fill="none" d="M-55.357-61.542h35.617"/><path fill="none" stroke-linecap="round" stroke-linejoin="round" d="M-21.62-63.942c.38 1.44 1.227 2.12 2.08 2.4-.853.28-1.7.96-2.08 2.4"/><text x="-37.028" y="-41.883" stroke="none" font-family="cmmi7" font-size="7" transform="translate(-2.662 -23.374)">f</text><path fill="none" d="M-63.612-55.183v26.2"/><path fill="none" stroke-linecap="round" stroke-linejoin="round" d="M-61.212-30.862c-1.44.38-2.12 1.226-2.4 2.08-.28-.854-.96-1.7-2.4-2.08"/><text x="-37.028" y="-41.883" stroke="none" font-family="cmmi7" font-size="7" transform="translate(-33.09 .826)">g</text><path fill="none" d="M-10.791-55.183v26.2"/><path fill="none" stroke-linecap="round" stroke-linejoin="round" d="M-8.391-30.862c-1.44.38-2.12 1.226-2.4 2.08-.28-.854-.96-1.7-2.4-2.08"/><text x="-37.028" y="-41.883" stroke="none" font-family="cmmi7" font-size="7" transform="translate(28.59 2.43)">h</text><path fill="none" d="M-55.175-20.39h35.2"/><path fill="none" stroke-linecap="round" stroke-linejoin="round" d="M-21.855-22.79c.38 1.44 1.227 2.12 2.08 2.4-.853.28-1.7.96-2.08 2.4"/><text x="-37.028" y="-41.883" stroke="none" font-family="cmmi7" font-size="7" transform="translate(-2.557 28.707)">k</text></g></svg></div><div style="color:#888"><em>An example commutative diagram, expressing the equality $h\circ f=k\circ g$.</em> &mdash; illustration, not machine-checked</div>
# <div class="tex2jax_ignore"><em>Here is an example of a commutative diagram, where \(h\circ f=k\circ g\):
#
# [Diagram rendered above]</em></div>

# %%
int! \int \frac {dx} (x^{\frac 1 2} + x^{\frac 1 3})
# Out:
# <div style="margin-top:4px"><strong>verified chain</strong> <span style="color:#888">&mdash; rendered from the selected ledger spine</span></div><table style="border-collapse:collapse"><tr><th style="padding:2px 12px 2px 0;text-align:left;border-bottom:1px solid #8884">step</th><th style="padding:2px 12px 2px 0;text-align:left;border-bottom:1px solid #8884">move</th><th style="padding:2px 12px 2px 0;text-align:left;border-bottom:1px solid #8884">result</th><th style="padding:2px 12px 2px 0;text-align:left;border-bottom:1px solid #8884">check</th></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s7</code><div class="tex2jax_ignore" style="color:#888;font-size:85%">new chain; no marker</div></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>integrate_substitute</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$\int \frac{6u^3}{u+1} \, d u$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s8</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>integrate_rewrite</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$\int \left(6u^2-6u+6-\frac{6}{u+1}\right) \, d u$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s9</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>integrate_linearity</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$\int 6u^{2} \, d u - \int 6u \, d u + \int 6 \, d u - \int \frac {6} {u+1} \, d u$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">exact</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s10</code><div class="tex2jax_ignore" style="color:#888;font-size:85%">new chain; no marker</div></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>integrate_power_rule</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$2u^{3} + C$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s11</code><div class="tex2jax_ignore" style="color:#888;font-size:85%">new chain; no marker</div></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>integrate_power_rule</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$3u^{2} + C$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s12</code><div class="tex2jax_ignore" style="color:#888;font-size:85%">new chain; no marker</div></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>integrate_power_rule</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$6u + C$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s13</code><div class="tex2jax_ignore" style="color:#888;font-size:85%">new chain; no marker</div></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>integrate_substitute</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$\int \frac{6}{v} \, d v$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s14</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-al ...
# <div class="tex2jax_ignore"><em>Verified for the assumption \(x&gt;0\), with one fresh \(+C\).</em></div>
# <div style="color:#888">rests on 1 stated premise, not derived here: \(\frac{1}{x^{\frac{1}{2}}+x^{\frac{1}{3}}}\)</div>
# <div style="color:#888">assumptions: $x > 0$</div>
# $2x^{\frac {1} {2}}-3x^{\frac {1} {3}}+C+6x^{\frac {1} {6}}-6 \ln\left ((x^{\frac {1} {6}}+1) \right )$

# %%
 prove! \lim_{n \to \infty} \frac{n}{2^n} = 0
# Out:
# <div class="tex2jax_ignore" style="color:#666"><code>s1</code> <em>Classification: a sequence limit, handled by the limits workflow.</em></div>
# <div class="tex2jax_ignore" style="color:#666"><code>s2</code> <em>The direct limit table has no rule; branch to a checked l&#x27;Hopital reduction.</em></div>
# <div><code>s3#6476faa [ok] limit_lhopital</code> &nbsp;$\lim_{n \to \infty} \frac{n}{2^n} \;\Longrightarrow\; \lim_{n \to \infty} \frac{1}{{2}^{n} \ln\left(2\right)}$</div><div style="margin-left:2em;color:#888">assumes ${n}$ and ${2^n}$ are differentiable in a punctured neighborhood of the approach point</div><div style="margin-left:2em;color:#888">assumes ${2}^{n} \ln\left(2\right) \ne 0$ in that punctured neighborhood</div><div style="margin-left:2em;color:#888">assumes the transformed limit exists or diverges to infinity</div>
# <div><code>s4#cc2409e [ok] limit_table</code> &nbsp;$\lim_{n \to \infty} \frac{1}{{2}^{n} \ln\left(2\right)} \;\Longrightarrow\; 0$</div>
# <div style="color:#8a5a00"><strong>CLAIM c1: CONDITIONAL</strong> &mdash; 2 checked step(s), 3 assumption(s)<br>$\lim_{n \to \infty} \frac{n}{2^n} = 0$</div>
# <div class="tex2jax_ignore"><em><strong>agent narrative — unverified:</strong> The claim is mechanically checked: \(\displaystyle \lim_{n\to\infty}\frac{n}{2^n}=0\).</em></div>
# <div style="color:#888">assumptions: ${n}$ and ${2^n}$ are differentiable in a punctured neighborhood of the approach point; ${2}^{n} \ln\left(2\right) \ne 0$ in that punctured neighborhood; the transformed limit exists or diverges to infinity</div>
# ${0}$

# %%
conv! \sum_{n=1}^{\infty} \frac{(-1)^{n(n-1) / 2}}{2^n}
# Out:
# <div><code>s1#ea23455 [ok] series_partial_sums</code> &nbsp;$\sum_{n=1}^{\infty} \frac{(-1)^{n(n-1) / 2}}{2^{n}} \;\Longrightarrow\; \lim_{m \to \infty} \sum_{n=1}^{m} \frac {(-1)^{n(n-{1})/{2}}} {2^{n}}$</div><div style="margin-left:2em;color:#888">assumes by definition the infinite sum equals the limit of its partial sums when that limit exists; if the limit does not exist the sum diverges and has no value</div>
# <div><code>s2#f429b5a [ok] (branch) series_converges</code> &nbsp;$\sum_{n=1}^{\infty} \frac{(-1)^{n(n-1) / 2}}{2^{n}} \;\Longrightarrow\; \sum_{n=1}^{\infty} \left| \frac {(-1)^{n(n-{1})/{2}}} {2^{n}} \right| \le 1$</div><div style="margin-left:2em;color:#888">assumes the dominating bound $\left| \frac {(-1)^{n(n-{1})/{2}}} {2^{n}} \right| \le \frac{1}{2^{n}}$ is assumed for every integer $n \ge 1$; it was spot-checked at 8 sample indices</div><div style="margin-left:2em;color:#888">assumes by monotone convergence the absolute partial sums, bounded by the closed tail value, converge; hence the series converges absolutely</div>
# <div class="tex2jax_ignore"><em>The series converges absolutely: `series_partial_sums` rewrote the sum definitionally, then `series_converges` with the dominating geometric term `1/2^n` recorded `|(-1)^{n(n-1)/2}/2^n| ≤ 1/2^n` and the closed tail bound `∑|·| ≤ 1`, giving absolute convergence.</em></div>
# <div style="color:#888">assumptions: by definition the infinite sum equals the limit of its partial sums when that limit exists; if the limit does not exist the sum diverges and has no value; the dominating bound $\left| \frac {(-1)^{n(n-{1})/{2}}} {2^{n}} \right| \le \frac{1}{2^{n}}$ is assumed for every integer $n \ge 1$; it was spot-checked at 8 sample indices; by monotone convergence the absolute partial sums, bounded by the closed tail value, converge; hence the series converges absolutely</div>
# $\sum_{n={1}}^{\infty}\left | \frac  {(-{1})^{n(n-{1})/{2}}} {{2}^n}\right | \le {1}$

# %%
do! Establish \sum_{k=0}^{\infty} (\frac{1}{2})^k = 2 with verified tactics only:
series_partial_sums, a checked closed form, then the limit |chain. Then render
one tikz figure — a proof-without-words dissection: a 2×1 rectangle cut into
pieces of area 1, 1/2, 1/4, 1/8, 1/16, ..., each piece a rectangle obtained by
halving the remaining space, alternating horizontal and vertical cuts, each
labeled with its area, the first six pieces shaded in graded tones, and the
uncut remainder left white. Title the figure with the ledger's final value.
The figure is an illustration; only the ledger establishes the value.
# Out:
# <div style="margin-top:4px"><strong>verified chain</strong> <span style="color:#888">&mdash; rendered from the selected ledger spine</span></div><table style="border-collapse:collapse"><tr><th style="padding:2px 12px 2px 0;text-align:left;border-bottom:1px solid #8884">step</th><th style="padding:2px 12px 2px 0;text-align:left;border-bottom:1px solid #8884">move</th><th style="padding:2px 12px 2px 0;text-align:left;border-bottom:1px solid #8884">result</th><th style="padding:2px 12px 2px 0;text-align:left;border-bottom:1px solid #8884">check</th></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s1</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>series_partial_sums</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$\lim_{n \to \infty} \sum_{k=0}^{n} ( \frac {1} {2})^k$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">exact <span style="color:#888">+1 assum.</span></td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s2</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>sum_closed_form</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$\lim_{n \to \infty} \left(2-(\frac{1}{2})^{n}\right)$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree <span style="color:#888">+1 assum.</span></td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s3</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>limit_linearity</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$\lim_{n \to \infty} 2 - \lim_{n \to \infty} ( \frac {1} {2})^n$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">exact <span style="color:#888">+2 assum.</span></td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s4</code><div class="tex2jax_ignore" style="color:#888;font-size:85%">new chain; no marker</div></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>limit_table</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$2$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">exact</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s5</code><div class="tex2jax_ignore" style="color:#888;font-size:85%">new chain; no marker</div></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>limit_table</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$0$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s6</code><div class="tex2jax_ignore" style="color:#888;font-size:85%">new chain; no marker</div></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>limit_assemble</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$2$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree <span style="color:#888">+2 assum.</span></td></tr></table>
# <div class="tex2jax_ignore" style="max-width:640px;overflow-x:auto"><svg xmlns="http://www.w3.org/2000/svg" width="228.689" height="162.525" viewBox="-72 -72 171.517 121.894"><defs><style type="text/css">@font-face{font-family:"cmsy8";src:url(data:font/ttf;base64,...) format("truetype");}@font-face{font-family:"cmex10";src:url(data:font/ttf;base64,...) format("truetype");}@font-face{font-family:"cmmi8";src:url(data:font/ttf;base64,...) format("truetype");}@font-face{font-family:"cmr8";src:url(data:font/ttf;base64,...) format("truetype");}@font-face{font-family:"cmr12";src:url(data:font/ttf;base64,...) format("truetype");}@font-face{font-family:"cmr9";src:url(data:font/ttf;base64,...) format("truetype");}@font-face{font-family:"cmr6";src:url(data:font/ttf;base64,...) format("truetype");}@font-face{font-family:"cmr5";src:url(data:font/ttf;base64,...) format("truetype");}@font-face{font-family:"cmsy7";src:url(data:font/ttf;base64,...) format("truetype");}</style></defs><g stroke="#000" stroke-miterlimit="10" stroke-width=".4"><g stroke="none"><text x="-68.37" y="36.224" font-family="cmsy8" font-size="8" transform="translate(51.7 -99.92)">1</text><text x="-71.342" y="39.224" font-family="cmex10" font-size="10" transform="translate(51.7 -99.92)">X</text><text x="-71.87" y="61.446" font-family="cmmi8" font-size="8" transform="translate(51.7 -99.92)">k</text><text x="-67.231" y="61.446" font-family="cmr8" font-size="8" transform="translate(51.7 -99.92)">=0</text><text x="-54.37" y="34.624" font-family="cmex10" font-size="10" transform="translate(51.7 -99.92)">&#181;</text><text x="-45.809" y="41.106" font-family="cmr12" font-size="12" transform="translate(51.7 -99.92)">1</text><path d="M5.89-53.897h5.876v.4H5.89z"/><text x="-45.809" y="57.455" font-family="cmr12" font-size="12" transform="translate(51.7 -99.92)">2</text><text x="-38.734" y="34.624" font-family="cmex10" font-size="10" transform="translate(51.7 -99.92)">&#182;</text><text x="-31.373" y="36.539" font-family="cmmi8" font-size="8" transform="translate(51.7 -99.92)">k</text><text x="-22.9" y="49.224" font-family="cmr12" font-size="12" transform="translate(51.7 -99.92)">=</text><text x="-10.428" y="49.224" font-family="cmr12" font-size="12" transform="translate(51.7 -99.92)">2</text></g><path fill="#66f" stroke="none" d="M-71.87 49.224v-85.358h85.358v85.358Zm85.358-85.358"/><path fill="#8c8cff" stroke="none" d="M13.488 49.224V6.544h85.359v42.68Zm85.359-42.68"/><path fill="#aeaeff" stroke="none" d="M13.488 6.545v-42.68h42.68v42.68Zm42.68-42.68"/><path fill="#cacaff" stroke="none" d="M56.167 6.545v-21.34h42.68v21.34Zm42.68-21.34"/><path fill="#e1e1ff" stroke="none" d="M56.167-14.795v-21.34h21.34v21.34Zm21.34-21.34"/><path fill="#f3f3ff" stroke="none" d="M77.507-14.795v-10.67h21.34v10.67Zm21.34-10.67"/><path fill="none" stroke-width=".8" d="M-71.87 49.224v-85.358H98.847v85.358ZM13.488 49.224v-85.358M13.488 6.545h85.359M56.167 6.545v-42.68M56.167-14.795h42.68M77.507-14.795v-21.34M77.507-25.465h21.34"/><text x="-71.87" y="49.224" stroke="none" font-family="cmr9" font-size="9" transform="translate(40.367 -39.78)">1</text><g stroke="none"><text x="-70.67" y="45.537" font-family="cmr6" font-size="6" transform="translate(125.004 -19.09)">1</text><path d="M54.334 27.684h3.667v.4h-3.667z"/><text x="-70.67" y="52.278" font-family="cmr6" font-size="6" transform="translate(125.004 -19.09)">2</text></g><g stroke="none"><text x="-70.67" y="45.537" font-family="cmr6" font-size="6" transform="translate(103.665 -61.769)">1</text><path d="M32.995-14.995h3.667v.4h-3.667z"/><text x="-70.67" y="52.278" font-family="cmr6" font-size="6" transform="translate(103.665 -61.769)">4</text></g><g stroke="none"><text x="-70.67" y="46.537" font-family="cmr5" font-size="5" transform="translate(146.476 -51.599)">1</text><path d="M75.806-4.325h3.403v.4h-3.403z"/><text x="-70.67" y="51.633" font-family="cmr5" font-size="5" transform="translate(146.476 -51.599)">8</text></g><g stroke="none"><text x="-68.969" y=" ...
# <div class="tex2jax_ignore"><em>Verified result recorded; the TikZ dissection is included as an unverified illustration.</em></div>
# <div style="color:#888">rests on 1 stated premise, not derived here: \(\sum_{k=0}^{\infty} (\frac{1}{2})^k\)</div>
# <div style="color:#888">assumptions: by definition the infinite sum equals the limit of its partial sums when that limit exists; if the limit does not exist the sum diverges and has no value; the identity is checked on the integer domain only: $n$ is an integer with $n \ge -1$ (below 0 the empty-sum convention applies); $\lim_{n \to \infty} 2$ exists; $\lim_{n \to \infty} ( \frac {1} {2})^n$ exists</div>
# $2$

# %%
do! Re-derive \lim_{n \to \infty} \prod_{k=1}^{n} \frac{2k-1}{2k} = 0 as a
prove! -style chain: interpret the product, bound it with 1/\sqrt{2n+1}, close
by squeeze. Then render one tikz figure: the points p_n = \prod_{k=1}^{n}
\frac{2k-1}{2k} for n = 1..20 (compute them exactly as fractions before
plotting), the decaying envelope 1/\sqrt{2n+1} above them, the axis y = 0
below, with a brace or arrow marking the squeeze. Label the envelope with its
formula and note in the caption that the ordering p_n \le 1/\sqrt{2n+1} is a
recorded, spot-checked assumption.
# Out:
# <div><code>s9#15d23be [ok] (branch) prod_closed_form</code> &nbsp;$\prod_{k=1}^{n} \frac{2k-1}{2k} \;\Longrightarrow\; \frac{(2n)!}{2^{2n}(n!)^2}$</div><div style="margin-left:2em;color:#888">assumes the identity is checked on the integer domain only: $n$ is an integer with $n \ge 0$ (below 1 the empty-product convention applies)</div>
# <div><code>s10#0fc0ca4 [ok] (branch) prod_closed_form</code> &nbsp;$\lim_{n \to \infty} \prod_{k=1}^{n} \frac{2k-1}{2k} \;\Longrightarrow\; \lim_{n \to \infty} \frac {(2n)!} {2^{{2}n}(n!)^{2}}$</div><div style="margin-left:2em;color:#888">assumes the identity is checked on the integer domain only: $n$ is an integer with $n \ge 0$ (below 1 the empty-product convention applies)</div>
# <div><code>s11#01522a6 [ok] (branch) limit_table</code> &nbsp;$\lim_{n \to \infty} 0 \;\Longrightarrow\; 0$</div>
# <div><code>s12#33fe34b [ok] (branch) limit_table</code> &nbsp;$\lim_{n \to \infty} \frac{1}{\sqrt{2n+1}} \;\Longrightarrow\; 0$</div>
# <div><code>s13#51e3781 [ok] (branch) limit_squeeze</code> &nbsp;$\lim_{n \to \infty} \prod_{k=1}^{n} \frac{2k-1}{2k} \;\Longrightarrow\; 0$</div><div style="margin-left:2em;color:#888">assumes the squeeze ordering $0 \le \prod_{k={1}}^{n}\frac {2k-1} {2k} \le \frac {1} {\sqrt{2n+1}}$ holds for $n$ near $\infty$ (spot-checked at approach samples, assumed throughout the approach)</div>
# <div><img src="data:image/png;base64,..." style="max-width:640px"/></div><div style="color:#888"><em>Partial products $p_n = \prod_{k=1}^{n} \frac{2k-1}{2k}$ for $n=1,\dots,20$ (exact fractions), envelope $1/\sqrt{2n+1}$ above, axis $y=0$ below, with a brace annotation marking the squeeze. The ordering $p_n \le 1/\sqrt{2n+1}$ is a recorded, spot-checked assumption.</em> &mdash; illustration, not machine-checked</div>
# <div class="tex2jax_ignore"><em>The ledger is closed: the limit is mechanically verified as 0. The figure confirms the monotone decay and the squeeze envelope visually.
#
# **Verified chain:**
#
# 1. `prod_closed_form` rewrote the product as \((2n)!\,/\,(2^{2n}(n!)^2)\) — checked on integer \(n\).
# 2. `limit_table` → \(\lim_{n\to\infty} 0 = 0\) (lower bound).
# 3. `limit_table` → \(\lim_{n\to\infty} 1/\sqrt{2n+1} = 0\) (root-power decay, upper bound).
# 4. `limit_squeeze` clamped the original product between 0 and \(1/\sqrt{2n+1}\) (ordering spot-checked and recorded), concluding the limit equals 0.</em></div>
# <div style="color:#888">assumptions: by definition the infinite sum equals the limit of its partial sums when that limit exists; if the limit does not exist the sum diverges and has no value; the dominating bound $\left| \frac {(-1)^{n(n-{1})/{2}}} {2^{n}} \right| \le \frac{1}{2^{n}}$ is assumed for every integer $n \ge 1$; it was spot-checked at 8 sample indices; by monotone convergence the absolute partial sums, bounded by the closed tail value, converge; hence the series converges absolutely; by definition the infinite sum equals the limit of its partial sums when that limit exists; if the limit does not exist the sum diverges and has no value; the identity is checked on the integer domain only: $n$ is an integer with $n \ge -1$ (below 0 the empty-sum convention applies); $\lim_{n \to \infty} 2$ exists; $\lim_{n \to \infty} ( \frac {1} {2})^{n}$ exists; the identity is checked on the integer domain only: $n$ is an integer with $n \ge 0$ (below 1 the empty-product convention applies); the squeeze ordering $0 \le \prod_{k={1}}^{n}\frac {2k-1} {2k} \le \frac {1} {\sqrt{2n+1}}$ holds for $n$ near $\infty$ (spot-checked at approach samples, assumed throughout the approach)</div>
# ${0}$

# %%
do! For the matrices \pmatrix{1 & 2 \cr 3 & 4}, \pmatrix{0 & 1 \cr 1 & 0}
and \pmatrix{1 & 0 \cr 2 & 1}, compute the determinant of
\left(2\pmatrix{1 & 2 \cr 3 & 4} - \pmatrix{0 & 1 \cr 1 & 0}\right)^T
\pmatrix{1 & 0 \cr 2 & 1} step by step, and designate the determinant
as the result
# Out:
# <div><code>s1#c2286c1 [ok] mat_scale</code> &nbsp;$2\pmatrix{1 & 2 \cr 3 & 4} \;\Longrightarrow\; \pmatrix{2 & 4 \cr 6 & 8}$</div>
# <div><code>s2#1332f9f [ok] (branch) mat_add</code> &nbsp;$\pmatrix{2 & 4 \cr 6 & 8} - \pmatrix{0 & 1 \cr 1 & 0} \;\Longrightarrow\; \pmatrix{2 & 3 \cr 5 & 8}$</div>
# <div><code>s3#c7606a2 [ok] (branch) transpose</code> &nbsp;$\pmatrix{2 & 3 \cr 5 & 8}^T \;\Longrightarrow\; \pmatrix{2 & 5 \cr 3 & 8}$</div>
# <div><code>s4#0dbab75 [ok] (branch) mat_mul</code> &nbsp;$\pmatrix{2 & 5 \cr 3 & 8}\pmatrix{1 & 0 \cr 2 & 1} \;\Longrightarrow\; \pmatrix{12 & 5 \cr 19 & 8}$</div>
# <div><code>s5#d4b0bd2 [ok] det_2x2</code> &nbsp;$\pmatrix{12 & 5 \cr 19 & 8} \;\Longrightarrow\; 1$</div>
# <div style="margin-top:4px"><strong>verified chain</strong> <span style="color:#888">&mdash; rendered from the ledger</span></div><table style="border-collapse:collapse"><tr><th style="padding:2px 12px 2px 0;text-align:left;border-bottom:1px solid #8884">step</th><th style="padding:2px 12px 2px 0;text-align:left;border-bottom:1px solid #8884">move</th><th style="padding:2px 12px 2px 0;text-align:left;border-bottom:1px solid #8884">result</th><th style="padding:2px 12px 2px 0;text-align:left;border-bottom:1px solid #8884">check</th></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s1</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>mat_scale</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$\pmatrix{2 & 4 \cr 6 & 8}$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s2</code><div style="color:#888;font-size:85%">(branch)</div></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>mat_add</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$\pmatrix{2 & 3 \cr 5 & 8}$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s3</code><div style="color:#888;font-size:85%">(branch)</div></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>transpose</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$\pmatrix{2 & 5 \cr 3 & 8}$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s4</code><div style="color:#888;font-size:85%">(branch)</div></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>mat_mul</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$\pmatrix{12 & 5 \cr 19 & 8}$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s5</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>det_2x2</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$1$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree</td></tr></table>
# <div class="tex2jax_ignore"><em>The determinant is **1**.</em></div>
# ${1}$

# %%
do! show that (sin x + cos x)² − 1 = sin(2x)
# Out:
# <div><code>s1#a6ff1cf [ok] rewrite</code> &nbsp;$(\sin x + \cos x)^2 - 1 \;\Longrightarrow\; {\sin^{2}x+2 \sin x \cos x+ \cos^{2}x}-1$</div>
# <div><code>s2#a43083f [ok] rewrite_as</code> &nbsp;${\sin^{2}x+2 \sin x \cos x+ \cos^{2}x}-1 \;\Longrightarrow\; \sin^2 x + \cos^2 x + 2 \sin x \cos x - 1$</div>
# <div><code>s3#e14a424 [ok] rewrite_as</code> &nbsp;$\sin^2 x + \cos^2 x + 2 \sin x \cos x - 1 \;\Longrightarrow\; 1 + 2 \sin x \cos x - 1$</div>
# <div><code>s4#6ee201b [ok] expand</code> &nbsp;$1 + 2 \sin x \cos x - 1 \;\Longrightarrow\; 2 \sin x \cos x$</div>
# <div><code>s5#3d4723c [ok] rewrite_as</code> &nbsp;$2 \sin x \cos x \;\Longrightarrow\; \sin(2x)$</div>
# <div><code>s6#a6ff1cf [ok] rewrite</code> &nbsp;$(\sin x + \cos x)^2 - 1 \;\Longrightarrow\; {\sin^{2}x+2 \sin x \cos x+ \cos^{2}x}-1$</div>
# <div><code>s7#1925190 [ok] rewrite_as</code> &nbsp;${\sin^{2}x+2 \sin x \cos x+ \cos^{2}x}-1 \;\Longrightarrow\; 1 + 2 \sin x \cos x - 1$</div>
# <div><code>s8#6ee201b [ok] expand</code> &nbsp;$1 + 2 \sin x \cos x - 1 \;\Longrightarrow\; 2 \sin x \cos x$</div>
# <div><code>s9#3d4723c [ok] rewrite_as</code> &nbsp;$2 \sin x \cos x \;\Longrightarrow\; \sin(2x)$</div>
# <div style="color:#176b2c"><strong>CLAIM c1: ESTABLISHED</strong> &mdash; 4 checked step(s), 0 assumption(s)<br>$(\sin x + \cos x)^2 - 1 = \sin(2x)$</div>
# <div style="margin-top:4px"><strong>verified chain</strong> <span style="color:#888">&mdash; rendered from the selected ledger spine</span></div><table style="border-collapse:collapse"><tr><th style="padding:2px 12px 2px 0;text-align:left;border-bottom:1px solid #8884">step</th><th style="padding:2px 12px 2px 0;text-align:left;border-bottom:1px solid #8884">move</th><th style="padding:2px 12px 2px 0;text-align:left;border-bottom:1px solid #8884">result</th><th style="padding:2px 12px 2px 0;text-align:left;border-bottom:1px solid #8884">check</th></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s1</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>rewrite</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">${\sin^{2}x+2 \sin x \cos x+ \cos^{2}x}-1$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s2</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>rewrite_as</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$\sin^2 x + \cos^2 x + 2 \sin x \cos x - 1$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s3</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>rewrite_as</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$1 + 2 \sin x \cos x - 1$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s4</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>expand</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$2 \sin x \cos x$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s5</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>rewrite_as</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$\sin(2x)$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s6</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>rewrite</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">${\sin^{2}x+2 \sin x \cos x+ \cos^{2}x}-1$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s7</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>rewrite_as</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$1 + 2 \sin x \cos x - 1$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s8</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>expand</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$2 \sin x \cos x$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s9</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>rewrite_as</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$\sin(2x)$</td><td style="padding:2px 12px 2px ...
# <div class="tex2jax_ignore"><em>The identity $(\sin x + \cos x)^2 - 1 = \sin(2x)$ has been established.</em></div>
# <div style="color:#888">rests on 1 stated premise, not derived here: \((\sin x + \cos x)^2 - 1\)</div>
# $\sin (2x)$

# %%
solve! x^2 - x \gt 6
# Out:
# <div style="margin-top:4px"><strong>verified chain</strong> <span style="color:#888">&mdash; rendered from the selected ledger spine</span></div><table style="border-collapse:collapse"><tr><th style="padding:2px 12px 2px 0;text-align:left;border-bottom:1px solid #8884">step</th><th style="padding:2px 12px 2px 0;text-align:left;border-bottom:1px solid #8884">move</th><th style="padding:2px 12px 2px 0;text-align:left;border-bottom:1px solid #8884">result</th><th style="padding:2px 12px 2px 0;text-align:left;border-bottom:1px solid #8884">check</th></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s6</code><div class="tex2jax_ignore" style="color:#888;font-size:85%">new chain; no marker</div></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>apply_both_sides - 6</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$x^{2}-x - 6 \gt 6 - 6$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s7</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>expand</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$x^{2}-x-6 \gt 0$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s8</code><div class="tex2jax_ignore" style="color:#888;font-size:85%">new chain; no marker</div></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>quadratic_roots</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$x=-2 \lor x=3$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s9</code><div class="tex2jax_ignore" style="color:#888;font-size:85%">new chain; no marker</div></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>substitute</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$(-2)^{2}-(-2)-6$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s10</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>evaluate</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$0$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s11</code><div class="tex2jax_ignore" style="color:#888;font-size:85%">new chain; no marker</div></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>substitute</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$(3)^{2}-(3)-6$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s12</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>evaluate</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$0$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s13</code><div class="tex2jax_ignore" style="color:#888;font-size:85%">new chain; no marker</div></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>factor_quadratic</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$\left(x - 3\right)\left(x + 2\right) \gt 0$</td><td style="padding:2px 12 ...
# <div class="tex2jax_ignore"><em>Verified result: \(x&lt;-2\lor x&gt;3\).</em></div>
# $x \lt -2 \lor x \gt 3$

# %%
do! plot interval \displaystyle x \lt -2 \lor x \gt 3
# Out:
# <div class="tex2jax_ignore" style="max-width:640px;overflow-x:auto"><svg xmlns="http://www.w3.org/2000/svg" width="379.903" height="28.384" viewBox="-72 -72 284.927 21.288"><defs><style type="text/css">@font-face{font-family:"cmsy10";src:url(data:font/ttf;base64,...) format("truetype");}@font-face{font-family:"cmr10";src:url(data:font/ttf;base64,...) format("truetype");}</style></defs><g stroke="#000" stroke-miterlimit="10" stroke-width=".4"><path fill="none" d="M-72.07-68.54h282.527"/><path stroke="none" d="m212.457-68.54-3.2-1.6 1.2 1.6-1.2 1.6"/><path fill="none" d="M13.288-71.954v6.828"/><g stroke="none" font-size="10"><text x="70.194" y="-68.54" font-family="cmsy10" transform="translate(-63.294 13.392)">&#161;</text><text x="77.972" y="-68.54" font-family="cmr10" transform="translate(-63.294 13.392)">2</text></g><path fill="none" d="M155.552-71.954v6.828"/><text x="70.194" y="-68.54" stroke="none" font-family="cmr10" font-size="10" transform="translate(82.858 13.392)">3</text><g fill="#00f" stroke="#00f" stroke-width="1.2"><path fill="none" d="M9.874-68.54h-67.363"/><path stroke="none" d="m-60.69-68.54 5.12 2.56-1.92-2.56 1.92-2.56"/></g><g fill="#00f" stroke="#00f" stroke-width="1.2"><path fill="none" d="M158.966-68.54h38.91"/><path stroke="none" d="m201.077-68.54-5.12-2.56 1.92 2.56-1.92 2.56"/></g><path fill="#fff" stroke="#00f" stroke-width="1.2" d="M16.418-68.54a3.13 3.13 0 1 0-6.26 0 3.13 3.13 0 0 0 6.26 0ZM158.682-68.54a3.13 3.13 0 1 0-6.26 0 3.13 3.13 0 0 0 6.26 0Zm-3.13 0"/></g></svg></div><div style="color:#888"><em>Number line for $x&lt;-2\lor x&gt;3$.</em> &mdash; illustration, not machine-checked</div>
# <div class="tex2jax_ignore"><em>The number-line plot is shown above; the endpoints \(-2\) and \(3\) are excluded.</em></div>

# %%
factor! x^3-3x^2+4
# Out:
# <div style="margin-top:4px"><strong>verified chain</strong> <span style="color:#888">&mdash; rendered from the selected ledger spine</span></div><table style="border-collapse:collapse"><tr><th style="padding:2px 12px 2px 0;text-align:left;border-bottom:1px solid #8884">step</th><th style="padding:2px 12px 2px 0;text-align:left;border-bottom:1px solid #8884">move</th><th style="padding:2px 12px 2px 0;text-align:left;border-bottom:1px solid #8884">result</th><th style="padding:2px 12px 2px 0;text-align:left;border-bottom:1px solid #8884">check</th></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s1</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>substitute</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$(2)^{3}-3(2)^{2}+4$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s2</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>evaluate</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$0$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s3</code><div class="tex2jax_ignore" style="color:#888;font-size:85%">new chain; no marker</div></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>rewrite_as</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$(x-2)(x^2-x-2)$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s4</code><div class="tex2jax_ignore" style="color:#888;font-size:85%">new chain; no marker</div></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>factor_quadratic</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$\left(x - 2\right)\left(x + 1\right)$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree</td></tr><tr><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>s5</code><div class="tex2jax_ignore" style="color:#888;font-size:85%">new chain; no marker</div></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top"><code>rewrite_as</code></td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top">$(x-2)(x-2)(x+1)$</td><td style="padding:2px 12px 2px 0;text-align:left;vertical-align:top;color:#176b2c">agree</td></tr></table>
# <div class="tex2jax_ignore"><em>Over the integers/rationals, the verified factorization is recorded.</em></div>
# $(x-2)(x-2)(x+1)$
