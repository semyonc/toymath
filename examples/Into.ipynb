# %%
do! differentiate x^3−3x, find where the derivative is zero, plot with those points marked
# Out:
# <details style="margin:2px 0"><summary style="cursor:pointer;color:#888">agent turns &mdash; 7 steps &middot; 7 checked <span style="font-size:90%">(click to expand)</span></summary><div style="margin:4px 0 4px 1em;border-left:2px solid #eee;padding-left:.8em"><div><code>s1#bd05e44 [ok] differentiate</code> &nbsp;$x^3-3x \;\Longrightarrow\; 3x^{2}-3$</div><div><code>s2#9c91ac3 [ok] quadratic_roots</code> &nbsp;$3x^{2}-3 \;\Longrightarrow\; x=-1 \lor x=1$</div><div><code>s3#4f609ca [ok] (new chain; no marker) substitute</code> &nbsp;$x^3-3x \;\Longrightarrow\; (-1)^{3}-3(-1)$</div><div><code>s4#951cc35 [ok] evaluate</code> &nbsp;$(-1)^{3}-3(-1) \;\Longrightarrow\; 2$</div><div><code>s5#aecce7b [ok] (new chain; no marker) substitute</code> &nbsp;$x^3-3x \;\Longrightarrow\; (1)^{3}-3(1)$</div><div><code>s6#0e06157 [ok] evaluate</code> &nbsp;$(1)^{3}-3(1) \;\Longrightarrow\; -2$</div><div><code>s7#c5e0ab7 [ok] (new chain; no marker) points_assemble</code> &nbsp;$x=-1 \lor x=1 \;\Longrigh
# ...

# %%
do! draw an example of the commutative diagram
# Out:
# <div style="max-width:640px;overflow-x:auto"><img src="data:image/svg+xml;base64,..." style="max-width:640px"/></div><div style="color:#888"><em>An example of a commutative diagram.</em> &mdash; illustration, not machine-checked</div>
# <div class="tex2jax_ignore"><em>Here is an example commutative square.</em></div>
# <div style="color:#888">rests on 1 stated premise, not derived here: \(x^3-3x\)</div>

# %%
int! \int \frac {dx} (x^{\frac 1 2} + x^{\frac 1 3})
# Out:
# <details style="margin:2px 0"><summary style="cursor:pointer;color:#888">agent turns &mdash; 16 steps &middot; 16 checked <span style="font-size:90%">(click to expand)</span></summary><div style="margin:4px 0 4px 1em;border-left:2px solid #eee;padding-left:.8em"><div><code>s8#f9b009f [ok] (new chain; no marker) integrate_substitute</code> &nbsp;$\frac{1}{x^{\frac{1}{2}}+x^{\frac{1}{3}}} \;\Longrightarrow\; \int \frac{6u^3}{u+1} \, d u$</div><div><code>s9#f79ad16 [ok] integrate_rewrite</code> &nbsp;$\frac{6u^3}{u+1} \;\Longrightarrow\; \int \left(6u^2-6u+6-\frac{6}{u+1}\right) \, d u$</div><div><code>s10#c18558b [ok] integrate_linearity</code> &nbsp;$\int \left(6u^2-6u+6-\frac{6}{u+1}\right) \, d u \;\Longrightarrow\; \int 6u^{2} \, d u - \int 6u \, d u + \int 6 \, d u - \int \frac {6} {u+1} \, d u$</div><div><code>s11#7d128be [ok] (new chain; no marker) integrate_power_rule</code> &nbsp;$6u^{2} \;\Longrightarrow\; 2u^{3} + C$</div><div><code>s12#7cbb449 [ok] substitute</code> &nbsp;$
# ...

# %%
 prove! \lim_{n \to \infty} \frac{n}{2^n} = 0
# Out:
# <details style="margin:2px 0"><summary style="cursor:pointer;color:#888">agent turns &mdash; 2 steps &middot; 2 checked &middot; 2 notes <span style="font-size:90%">(click to expand)</span></summary><div style="margin:4px 0 4px 1em;border-left:2px solid #eee;padding-left:.8em"><div class="tex2jax_ignore" style="color:#666"><code>s24</code> <em>This is a sequence-limit claim; use a comparison route.</em></div><div class="tex2jax_ignore" style="color:#666"><code>s25</code> <em>The table rule does not cover the quotient directly; use l&#x27;Hopital.</em></div><div><code>s26#a261320 [ok] (new chain; no marker) limit_lhopital</code> &nbsp;$\lim_{n \to \infty} \frac{n}{2^n} \;\Longrightarrow\; \lim_{n \to \infty} \frac{1}{({2}^n) \ln\left (2 \right )}$</div><div style="margin-left:2em;color:#888">assumes ${n}$ and ${2^n}$ are differentiable in a punctured neighborhood of the approach point</div><div style="margin-left:2em;color:#888">assumes $({2}^n) \ln\left (2 \right ) \ne 0$ in that pun
# ...

# %%
conv! \sum_{n=1}^{\infty} \frac{(-1)^{n(n-1) / 2}}{2^n}
# Out:
# <details style="margin:2px 0"><summary style="cursor:pointer;color:#888">agent turns &mdash; 3 steps &middot; 3 checked <span style="font-size:90%">(click to expand)</span></summary><div style="margin:4px 0 4px 1em;border-left:2px solid #eee;padding-left:.8em"><div><code>s28#51eb6f5 [ok] (new chain; no marker) series_partial_sums</code> &nbsp;$\sum_{n=1}^{\infty} \frac{(-1)^{n(n-1)/2}}{2^n} \;\Longrightarrow\; \lim_{m \to \infty} \sum_{n=1}^{m} \frac {(-1)^{n(n-1)/2}} {2^n}$</div><div style="margin-left:2em;color:#888">assumes by definition the infinite sum equals the limit of its partial sums when that limit exists; if the limit does not exist the sum diverges and has no value</div><div><code>s29#64fc1ab [ok] sum_closed_form</code> &nbsp;$\lim_{m \to \infty} \sum_{n=1}^{m} \frac {(-1)^{n(n-1)/2}} {2^n} \;\Longrightarrow\; \lim_{m \to \infty} \left(\frac{1}{5}+\frac{(-1)^{m(m-1)/2}}{5\cdot2^m}-\frac{2(-1)^{m(m+1)/2}}{5\cdot2^m}\right)$</div><div style="margin-left:2em;color:#888">ass
# ...

# %%
do! Establish \sum_{k=0}^{\infty} (\frac{1}{2})^k = 2 with verified tactics only:
series_partial_sums, a checked closed form, then the limit |chain. Then render
one tikz figure — a proof-without-words dissection: a 2×1 rectangle cut into
pieces of area 1, 1/2, 1/4, 1/8, 1/16, ..., each piece a rectangle obtained by
halving the remaining space, alternating horizontal and vertical cuts, each
labeled with its area, the first six pieces shaded in graded tones, and the
uncut remainder left white. Title the figure with the ledger's final value.
The figure is an illustration; only the ledger establishes the value.
# Out:
# <details style="margin:2px 0"><summary style="cursor:pointer;color:#888">agent turns &mdash; 6 steps &middot; 6 checked <span style="font-size:90%">(click to expand)</span></summary><div style="margin:4px 0 4px 1em;border-left:2px solid #eee;padding-left:.8em"><div><code>s31#9a2e8c5 [ok] (new chain; no marker) series_partial_sums</code> &nbsp;$\sum_{k=0}^{\infty} (\frac{1}{2})^k \;\Longrightarrow\; \lim_{n \to \infty} \sum_{k=0}^{n} ( \frac {1} {2})^k$</div><div style="margin-left:2em;color:#888">assumes by definition the infinite sum equals the limit of its partial sums when that limit exists; if the limit does not exist the sum diverges and has no value</div><div><code>s32#064b326 [ok] sum_closed_form</code> &nbsp;$\lim_{n \to \infty} \sum_{k=0}^{n} ( \frac {1} {2})^k \;\Longrightarrow\; \lim_{n \to \infty} \left(2-(\frac{1}{2})^{n}\right)$</div><div style="margin-left:2em;color:#888">assumes the identity is checked on the integer domain only: $n$ is an integer with $n \ge -1$ (bel
# ...

# %%
do! Re-derive \lim_{n \to \infty} \prod_{k=1}^{n} \frac{2k-1}{2k} = 0 as a
prove! -style chain: interpret the product, bound it with 1/\sqrt{2n+1}, close
by squeeze. Then render one tikz figure: the points p_n = \prod_{k=1}^{n}
\frac{2k-1}{2k} for n = 1..20 (compute them exactly as fractions before
plotting), the decaying envelope 1/\sqrt{2n+1} above them, the axis y = 0
below, with a brace or arrow marking the squeeze. Label the envelope with its
formula and note in the caption that the ordering p_n \le 1/\sqrt{2n+1} is a
recorded, spot-checked assumption.
# Out:
# <details style="margin:2px 0"><summary style="cursor:pointer;color:#888">agent turns &mdash; 5 steps &middot; 5 checked <span style="font-size:90%">(click to expand)</span></summary><div style="margin:4px 0 4px 1em;border-left:2px solid #eee;padding-left:.8em"><div><code>s37#11405a9 [ok] prod_from_ellipsis</code> &nbsp;$\frac{1}{2}\cdot\frac{3}{4}\cdots\frac{2n-1}{2n} \;\Longrightarrow\; \prod_{k=1}^{n} \frac {2k-1} {2k}$</div><div style="margin-left:2em;color:#888">assumes the ellipsis in $\frac {{1}} {{2}}\cdot\frac {{3}} {{4}}\cdot\ldots\cdot\frac {{2}n-{1}} {{2}n}$ continues the pattern of $\frac {2k-1} {2k}$: the product is read as $\prod_{k=1}^{n} \frac {2k-1} {2k}$</div><div><code>s38#3388cb5 [ok] (new chain; no marker) series_partial_sums</code> &nbsp;$\prod_{k=1}^{\infty}\frac{2k-1}{2k} \;\Longrightarrow\; \lim_{n \to \infty} \prod_{k=1}^{n} \frac {2k-1} {2k}$</div><div style="margin-left:2em;color:#888">assumes by definition the infinite product equals the limit of its part
# ...

# %%
do! For the matrices \pmatrix{1 & 2 \cr 3 & 4}, \pmatrix{0 & 1 \cr 1 & 0}
and \pmatrix{1 & 0 \cr 2 & 1}, compute the determinant of
\left(2\pmatrix{1 & 2 \cr 3 & 4} - \pmatrix{0 & 1 \cr 1 & 0}\right)^T
\pmatrix{1 & 0 \cr 2 & 1} step by step, and designate the determinant
as the result
# Out:
# <details style="margin:2px 0"><summary style="cursor:pointer;color:#888">agent turns &mdash; 5 steps &middot; 5 checked <span style="font-size:90%">(click to expand)</span></summary><div style="margin:4px 0 4px 1em;border-left:2px solid #eee;padding-left:.8em"><div><code>s42#c2286c1 [ok] (new chain; no marker) mat_scale</code> &nbsp;$2\pmatrix{1 & 2 \cr 3 & 4} \;\Longrightarrow\; \pmatrix{2 & 4 \cr 6 & 8}$</div><div><code>s43#1332f9f [ok] (new chain; no marker) mat_add</code> &nbsp;$\pmatrix{2 & 4 \cr 6 & 8} - \pmatrix{0 & 1 \cr 1 & 0} \;\Longrightarrow\; \pmatrix{2 & 3 \cr 5 & 8}$</div><div><code>s44#c7606a2 [ok] (new chain; no marker) transpose</code> &nbsp;$\pmatrix{2 & 3 \cr 5 & 8}^T \;\Longrightarrow\; \pmatrix{2 & 5 \cr 3 & 8}$</div><div><code>s45#0dbab75 [ok] (new chain; no marker) mat_mul</code> &nbsp;$\pmatrix{2 & 5 \cr 3 & 8}\pmatrix{1 & 0 \cr 2 & 1} \;\Longrightarrow\; \pmatrix{12 & 5 \cr 19 & 8}$</div><div><code>s46#d4b0bd2 [ok] det_2x2</code> &nbsp;$\pmatrix{12 & 5 \cr 1
# ...

# %%
do! show that (sin x + cos x)² − 1 = sin(2x)
# Out:
# <details style="margin:2px 0"><summary style="cursor:pointer;color:#888">agent turns &mdash; 6 steps &middot; 6 checked <span style="font-size:90%">(click to expand)</span></summary><div style="margin:4px 0 4px 1em;border-left:2px solid #eee;padding-left:.8em"><div><code>s47#1467854 [ok] (new chain; no marker) rewrite</code> &nbsp;$(\sin x+\cos x)^2-1=\sin(2x) \;\Longrightarrow\; {\sin^{2}x+2 \sin x \cos x+ \cos^{2}x-1}= \sin (2x)$</div><div><code>s48#a5ea5f1 [ok] rewrite_as</code> &nbsp;${\sin^{2}x+2 \sin x \cos x+\cos^{2}x-1}= \sin (2x) \;\Longrightarrow\; {\sin^{2}x+\cos^{2}x+2 \sin x \cos x-1}=\sin(2x)$</div><div><code>s49#dc427ad [ok] rewrite</code> &nbsp;${\sin^{2}x+\cos^{2}x+2 \sin x \cos x-1}=\sin(2x) \;\Longrightarrow\; {( \sin x)^{2}+{1- \sin^{2}x}+2( \sin x)( \cos x)-1}= \sin (2x)$</div><div><code>s50#24f1da8 [ok] expand</code> &nbsp;${( \sin x)^{2}+{1- \sin^{2}x}+2( \sin x)( \cos x)-1}= \sin (2x) \;\Longrightarrow\; 2 \sin x \cos x = \sin (2x)$</div><div><code>s51#90899e4
# ...

# %%
solve! x^2 - x \gt 6
# Out:
# <details style="margin:2px 0"><summary style="cursor:pointer;color:#888">agent turns &mdash; 18 steps &middot; 18 checked <span style="font-size:90%">(click to expand)</span></summary><div style="margin:4px 0 4px 1em;border-left:2px solid #eee;padding-left:.8em"><div><code>s53#1150e46 [ok] (new chain; no marker) apply_both_sides - 6</code> &nbsp;$x^2-x \gt 6 \;\Longrightarrow\; x^{2}-x - 6 \gt 6 - 6$</div><div><code>s54#7f42cac [ok] expand</code> &nbsp;$x^{2}-x - 6 \gt 6 - 6 \;\Longrightarrow\; x^{2}-x-6 \gt 0$</div><div><code>s55#e3ab504 [ok] (new chain; no marker) quadratic_roots</code> &nbsp;$x^{2}-x-6 \;\Longrightarrow\; x=-2 \lor x=3$</div><div><code>s56#aee8658 [ok] (new chain; no marker) substitute</code> &nbsp;$x^{2}-x-6 \;\Longrightarrow\; (-2)^{2}-(-2)-6$</div><div><code>s57#689d903 [ok] evaluate</code> &nbsp;$(-2)^{2}-(-2)-6 \;\Longrightarrow\; 0$</div><div><code>s58#37ab246 [ok] (new chain; no marker) substitute</code> &nbsp;$x^{2}-x-6 \;\Longrightarrow\; (3)^{2}-(3)-6$</
# ...

# %%
do! plot interval \displaystyle x \lt -2 \lor x \gt 3
# Out:
# <div style="max-width:640px;overflow-x:auto"><img src="data:image/svg+xml;base64,..." style="max-width:640px"/></div><div style="color:#888"><em>Number-line plot of $x&lt;-2\lor x&gt;3$.</em> &mdash; illustration, not machine-checked</div>
# <div class="tex2jax_ignore"><em>The plot shows \(x\in(-\infty,-2)\cup(3,\infty)\).</em></div>
# <div style="color:#888">rests on 15 stated premises, not derived here: \(x^3-3x\), \(\frac{1}{x^{\frac{1}{2}}+x^{\frac{1}{3}}}\), \(\lim_{n \to \infty} \frac{n}{2^n}\), \(\sum_{n=1}^{\infty} \frac{(-1)^{n(n-1)/2}}{2^n}\), \(\sum_{k=0}^{\infty} (\frac{1}{2})^k\), \(\frac{1}{2}\cdot\frac{3}{4}\cdots\frac{2n-1}{2n}\), \(\prod_{k=1}^{\infty}\frac{2k-1}{2k}\), \(\lim_{n \to \infty}\frac{1}{\sqrt{2n+1}}\), \(2\pmatrix{1 & 2 \cr 3 & 4}\), \(\pmatrix{2 & 4 \cr 6 & 8} - \pmatrix{0 & 1 \cr 1 & 0}\), \(\pmatrix{2 & 3 \cr 5 & 8}^T\), \(\pmatrix{2 & 5 \cr 3 & 8}\pmatrix{1 & 0 \cr 2 & 1}\), \((\sin x+\cos x)^2-1=\sin(2x)\), \(x^2-x \gt 6\), \(x^{2}-x-6\)</div>

# %%
factor! x^3-3x^2+4
# Out:
# <details style="margin:2px 0"><summary style="cursor:pointer;color:#888">agent turns &mdash; 5 steps &middot; 5 checked <span style="font-size:90%">(click to expand)</span></summary><div style="margin:4px 0 4px 1em;border-left:2px solid #eee;padding-left:.8em"><div><code>s71#ca773fc [ok] (new chain; no marker) substitute</code> &nbsp;$x^3-3x^2+4 \;\Longrightarrow\; (-1)^{3}-3(-1)^{2}+4$</div><div><code>s72#ad33138 [ok] evaluate</code> &nbsp;$(-1)^{3}-3(-1)^{2}+4 \;\Longrightarrow\; 0$</div><div><code>s73#0d727c2 [ok] (new chain; no marker) rewrite_as</code> &nbsp;$x^3-3x^2+4 \;\Longrightarrow\; (x+1)(x^2-4x+4)$</div><div><code>s74#c8b3b7c [ok] (new chain; no marker) factor_quadratic</code> &nbsp;$x^2-4x+4 \;\Longrightarrow\; \left(x - 2\right)^{2}$</div><div><code>s75#0015fe8 [ok] (new chain; no marker) rewrite_as</code> &nbsp;$(x+1)(x^2-4x+4) \;\Longrightarrow\; (x+1)(x-2)^2$</div></div></details>
# ...
